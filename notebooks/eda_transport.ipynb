# %%
import sys
import os
import re
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd
import plotly.express as px
import numpy as np
import geopandas as gpd
from pyproj import Transformer
from scripts.utils import split_column_at
from scripts.accent_cleaner import AccentCleaner
#from deep_translator import GoogleTranslator

# %% [markdown]
# ### Airports

# %%
# Read the GeoJSON file
gdf = gpd.read_file('../data/raw/spanish_airports.geojson')
# Ensure that the geometry column contains points
# Extract latitude and longitude from the geometry column
gdf['latitude'] = gdf.geometry.y
gdf['longitude'] = gdf.geometry.x

# Now drop the geometry column if you don't need it anymore
df_airports = gdf.drop(columns='geometry')

df_airports.rename(columns={"Texto": "airport_name", "OBJECTID": "airport_id", "lat": "latitude", "lon": "longitude"}, inplace=True)
df_airports
# Out:
#     airport_id                                  airport_name   latitude  \
# 0            1                           Aeropuerto de Jerez  36.743828
# 1            2                            Aeropuerto de Vigo  42.225740
# 2            3                         Aeropuerto de Badajoz  38.889845
# 3            4           Aeropuerto de Granada - Jaén F.G.L.  37.186826
# 4            5                         Aeropuerto de Almería  36.844781
# 5            6                      Aeropuerto de Salamanca   40.950757
# 6            7                           Aeropuerto de Ibiza  38.874352
# 7            8                       Aeropuerto de Lanzarote  28.951045
# 8            9                        Aeropuerto de La Palma  28.622084
# 9           10                 Aeropuerto de Tenerife Norte   28.485811
# 10          11                       Aeropuerto de La Gomera  28.031163
# 11          12                   Aeropuerto de Tenerife Sur   28.045488
# 12          13                    Aeropuerto de Gran Canaria  27.931111
# 13          14                       Aeropuerto de El Hierro  27.814841
# 14          15                        Aeropuerto de Asturias  43.562196
# 15          16                      Aeropuerto de Valladolid  41.709020
# 16          17                    Santander-Seve Ballesteros  43.426146
# 17          18                   Aeropuerto de San Sebastián  43.356409
# 18          19                          Aeropuerto de Bilbao  43.302507
# 19          20                         Aeropuerto de Córdoba  37.843869
# 20          21                        Aeropuerto de A Coruña  43.302718
# 21          22  Aeropuerto de Adolfo Suárez Madrid - Barajas  40.492080
# 22          23                        Aeropuerto de Albacete  38.949634
# 23          24                       Helipuerto de Algeciras  36.128808
# 24          25                Aeropuerto de Alicante - Elche  38.285826
# 25          26             Aeropuerto de Barcelona - El prat  41.296302
# 26          27                          Aeropuerto de Burgos  42.354330
# 27          28                           Helipuerto de Ceuta  35.892402
# 28          29                   Aeropuerto de Fuerteventura  28.450567
# 29          30            Aeropuerto de Girona - Costa Brava  41.900933
# 30          31                 Aeropuerto de Huesca Pirineos  42.076622
# 31          32                            Aeropuerto de León  42.589828
# 32          33             Aeropuerto de Logroño - Agoncillo  42.459595
# 33          34         Aeropuerto de Madrid - Cuatro vientos  40.370628
# 34          35          Aeropuerto de Málaga - Costa del Sol  36.676309
# 35          36                         Aeropuerto de Melilla  35.279232
# 36          37                         Aeropuerto de Menorca  39.864484
# 37          38             Aeropuerto de Murcia - San Javier  37.773074
# 38          39               Aeropuerto de Palma de Mallorca  39.549868
# 39          40                        Aeropuerto de Pamplona  42.765108
# 40          41                            Aeropuerto de Reus  41.146491
# 41          42                        Aeropuerto de Sabadell  41.520997
# 42          43                        Aeropuerto de Santiago  42.897422
# 43          44                         Aeropuerto de Sevilla  37.419749
# 44          45                       Aeropuerto de Son Bonet  39.601478
# 45          46                        Aeropuerto de Valencia  39.490969
# 46          47                         Aeropuerto de Vitoria  42.879158
# 47          48                        Aeropuerto de Zaragoza  41.670550
#
#     longitude
# 0   -6.062658
# 1   -8.630491
# 2   -6.821121
# 3   -3.778613
# 4   -2.371234
# 5   -5.502955
# 6    1.372669
# 7  -13.605020
# 8  -17.753653
# 9  -16.347639
# 10 -17.211970
# 11 -16.575306
# 12 -15.387094
# 13 -17.886954
# 14  -6.032618
# 15  -4.848254
# 16  -3.822816
# 17  -1.791606
# 18  -2.908358
# 19  -4.846947
# 20  -8.377502
# 21  -3.576319
# 22  -1.863164
# 23  -5.440776
# 24  -0.563349
# 25   2.085025
# 26  -3.621685
# 27  -5.306231
# 28 -13.866199
# 29   2.763776
# 30  -0.317633
# 31  -5.654463
# 32  -2.317277
# 33  -3.785103
# 34  -4.496700
# 35  -2.955935
# 36   4.221386
# 37  -0.816985
# 38   2.731825
# 39  -1.642774
# 40   1.158505
# 41   2.104792
# 42  -8.417961
# 43  -5.898624
# 44   2.705274
# 45  -0.480521
# 46  -2.731158
# 47  -1.060349

# %%
df_airports["airport_name"] = df_airports["airport_name"].str.replace(r"^Aeropuerto de ", "", regex=True)
df_airports.rename(columns={"airport_name": "airport"}, inplace=True)
df_airports["airport"] = df_airports["airport"].str.replace("-", " - ", regex=False)

df_airports.drop("airport_id", axis=1, inplace=True)
df_airports.head()
# Out:
#                    airport   latitude  longitude
# 0                    Jerez  36.743828  -6.062658
# 1                     Vigo  42.225740  -8.630491
# 2                  Badajoz  38.889845  -6.821121
# 3  Granada  -  Jaén F.G.L.  37.186826  -3.778613
# 4                  Almería  36.844781  -2.371234

# %%
airports_info = pd.read_csv("../data/raw/airports_info.csv")
airports_info.drop(["web-scraper-order", "web-scraper-start-url", "runways"], axis = 1, inplace = True)

# %%
airports_info.head()
# Out:
#                            airport y_passengers
# 0     Adolfo Suárez Madrid-Barajas   60 220 984
# 1                     Albacete[3]​        2 644
# 2  Alicante-Elche Miguel Hernández   15 747 678
# 3                          Almería      775 393
# 4                         Asturias    1 974 850

# %%
airports_info["airport"] = airports_info["airport"].str.replace(r"\[.*?\]", "", regex=True).str.strip()
airports_info["airport"] = airports_info["airport"].str.replace("-", "  -  ", regex=False)

# %%
airports_info["y_passengers"] = airports_info["y_passengers"].str.replace(r" ", "", regex=True)
airports_info["y_passengers"].astype(int)
# Out:
# 0     60220984
# 1         2644
# 2     15747678
# 3       775393
# 4      1974850
# 5        80181
# 6     49220984
# 7      6336441
# 8         4053
# 9         5938
# 10     1039429
# 11     1586463
# 12    13961638
# 13     6020413
# 14     1252022
# 15     8212943
# 16         276
# 17     8931598
# 18      904000
# 19       63442
# 20       16728
# 21        1956
# 22    22344373
# 23      501069
# 24     4045215
# 25      877796
# 26    31105987
# 27      197509
# 28     1045419
# 29        6207
# 30       21083
# 31      482662
# 32     3537445
# 33     8071524
# 34     1242089
# 35       10061
# 36     6120550
# 37    12337244
# 38     1368821
# 39      113318
# 40      301241
# 41     9948141
# 42      208923
# 43     1136157
# 44      309929
# 45      685690
# Name: y_passengers, dtype: int32

# %%
airports_info["airport"] = airports_info["airport"].replace("La Coruña", "A Coruña")

# %%
airports_info.sort_values(by = "airport", ascending = True).reset_index(inplace=True)
airports_info.head()
# Out:
#                              airport y_passengers
# 0     Adolfo Suárez Madrid - Barajas     60220984
# 1                          Albacete​         2644
# 2  Alicante - Elche Miguel Hernández     15747678
# 3                            Almería       775393
# 4                           Asturias      1974850

# %%
df_airports= df_airports.sort_values(by = "airport", ascending = True)
df_airports
# Out:
#                              airport   latitude  longitude
# 20                          A Coruña  43.302718  -8.377502
# 21  Adolfo Suárez Madrid  -  Barajas  40.492080  -3.576319
# 22                          Albacete  38.949634  -1.863164
# 24                Alicante  -  Elche  38.285826  -0.563349
# 4                            Almería  36.844781  -2.371234
# 14                          Asturias  43.562196  -6.032618
# 2                            Badajoz  38.889845  -6.821121
# 25             Barcelona  -  El prat  41.296302   2.085025
# 18                            Bilbao  43.302507  -2.908358
# 26                            Burgos  42.354330  -3.621685
# 19                           Córdoba  37.843869  -4.846947
# 13                         El Hierro  27.814841 -17.886954
# 28                     Fuerteventura  28.450567 -13.866199
# 29            Girona  -  Costa Brava  41.900933   2.763776
# 12                      Gran Canaria  27.931111 -15.387094
# 3            Granada  -  Jaén F.G.L.  37.186826  -3.778613
# 23           Helipuerto de Algeciras  36.128808  -5.440776
# 27               Helipuerto de Ceuta  35.892402  -5.306231
# 30                   Huesca Pirineos  42.076622  -0.317633
# 6                              Ibiza  38.874352   1.372669
# 0                              Jerez  36.743828  -6.062658
# 10                         La Gomera  28.031163 -17.211970
# 8                           La Palma  28.622084 -17.753653
# 7                          Lanzarote  28.951045 -13.605020
# 31                              León  42.589828  -5.654463
# 32             Logroño  -  Agoncillo  42.459595  -2.317277
# 33         Madrid  -  Cuatro vientos  40.370628  -3.785103
# 35                           Melilla  35.279232  -2.955935
# 36                           Menorca  39.864484   4.221386
# 37             Murcia  -  San Javier  37.773074  -0.816985
# 34          Málaga  -  Costa del Sol  36.676309  -4.496700
# 38                 Palma de Mallorca  39.549868   2.731825
# 39                          Pamplona  42.765108  -1.642774
# 40                              Reus  41.146491   1.158505
# 41                          Sabadell  41.520997   2.104792
# 5                         Salamanca   40.950757  -5.502955
# 17                     San Sebastián  43.356409  -1.791606
# 16      Santander - Seve Ballesteros  43.426146  -3.822816
# 42                          Santiago  42.897422  -8.417961
# 43                           Sevilla  37.419749  -5.898624
# 44                         Son Bonet  39.601478   2.705274
# 9                    Tenerife Norte   28.485811 -16.347639
# 11                     Tenerife Sur   28.045488 -16.575306
# 45                          Valencia  39.490969  -0.480521
# 15                        Valladolid  41.709020  -4.848254
# 1                               Vigo  42.225740  -8.630491
# 46                           Vitoria  42.879158  -2.731158
# 47                          Zaragoza  41.670550  -1.060349

# %%
# Show all rows and columns
pd.set_option("display.max_rows", None)  # Show all rows
pd.set_option("display.max_columns", None)  # Show all columns
airports = pd.merge(left = df_airports, right = airports_info, on= "airport", how="outer")
airports.to_csv("../data/marina.csv")

# %%
title = "Airports in Spain"

lats = df_airports.latitude
lons = df_airports.longitude

fig = px.scatter_map(df_airports, 
                     lat=lats, 
                     lon=lons,
                     color_continuous_scale=px.colors.carto.Aggrnyl,
                     zoom=5,
                     size_max=50  # Increase max size of markers
                     )

# Adjust the size reference to make small points more visible
fig.update_traces(marker=dict(sizeref=1000))  # Decrease this value to make points larger

fig.update_geos(fitbounds="locations")
fig.update_layout(height=1000, width=1000)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":50,"t":50,"l":50,"b":50})
fig.update_layout(
    coloraxis_colorbar=dict(title='asdf')
)
fig.update_layout(title="Airports in Spain ")

fig.show()

# %%
df_airports.to_csv("../data/processed/filtered_airports.csv", index=False)

# %% [markdown]
# ### Trains

# %%
df_trains = pd.read_csv("../data/raw/listado_completo_av_ld_md.csv", sep=";", decimal=",")
df_trains = df_trains.drop(["PAIS", "C.P.", "DIRECCIÓN"], axis = 1)
df_trains.rename(columns={" CÓDIGO": "station_code",
                          "DESCRIPCION": "station_name",
                          "LATITUD": "latitude",
                          "POBLACION": "municipality",
                          "PROVINCIA": "province",
                          "LONGITUD": "longitude"}, inplace=True)

# %%
df_trains.isnull().sum()

# %%
cleaner = AccentCleaner([df_trains], columns=["province", "municipality"])
cleaner.cleanAccents()
df_trains

# %%
df_trains["municipality_clean"] = df_trains["municipality_clean"].str.split("/", expand=False)
df_trains["province_clean"] = df_trains["province_clean"].str.split("/", expand=False)

df_trains["municipality_clean"] = df_trains["municipality_clean"].apply(
    lambda x: x[0] if len(x) == 1 else x[1]
)
df_trains["province_clean"] = df_trains["province_clean"].apply(
    lambda x: x[0] if len(x) == 1 else x[1]
)

# %%
df_trains.sample(20)

# %%
df_trains['station_name'] = df_trains['station_name'].str.title()
df_trains['municipality'] = df_trains['municipality'].str.lower()
df_trains['province'] = df_trains['province'].str.lower()

# %%
if len(df_trains["province"]):
    df_trains.drop(columns=["province", "municipality"], inplace=True)

df_trains

# %%
title = "Train Stations (LD, MD, High Speed) in Spain"

lats = df_trains.latitude
lons = df_trains.longitude

fig = px.scatter_map(df_trains, 
                     lat=lats, 
                     lon=lons,
                     hover_data=["municipality_clean", "station_name"], 
                     color_continuous_scale=px.colors.carto.Aggrnyl,
                     zoom=5,
                     size_max=50  # Increase max size of markers
                     )

# Adjust the size reference to make small points more visible
fig.update_traces(marker=dict(sizeref=1000))  # Decrease this value to make points larger

fig.update_geos(fitbounds="locations")
fig.update_layout(height=1000, width=1000)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":50,"t":50,"l":50,"b":50})
fig.update_layout(
    coloraxis_colorbar=dict(title='asdf')
)
fig.update_layout(title="Train Stations in Spain ")

fig.show()

# %%
df_trains.to_csv("../data/processed/filtered_trains.csv", index=False)
