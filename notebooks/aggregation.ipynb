# %%
import os
import pandas as pd

processed_dir = '../data/processed/filtered_files'
csv_files = [f for f in os.listdir(processed_dir) if f.endswith('.csv')]

dataframes = {}
for file in csv_files:
    df_name = os.path.splitext(file)[0]
    df_name = "df_" + df_name.split("_")[1]
    df_path = os.path.join(processed_dir, file)
    dataframes[df_name] = pd.read_csv(df_path, encoding="utf-8")
# Display the names of the loaded DataFrames

# %%
# Ensure that df_distances is available from the existing dataframes dictionary.
df_distances = dataframes.get("df_distances")
df_municipalities = dataframes.get("df_municipalities")
df_schools = dataframes.get("df_schools")
df_industry = dataframes.get("df_industry")
df_trains = dataframes.get("df_trains")
df_connectivity = dataframes.get("df_connectivity")
df_climate = dataframes.get("df_climate")
df_airports = dataframes.get("df_airports")
df_hospitals = dataframes.get("df_hospitals")
df_demographics = dataframes.get("df_demographics")
df_regional_trains = dataframes.get("df_regionaltrains")

# %%
df_demographics.head(2)
# Out:
#    cmun municipality_clean province_clean  0-17  18-24  25-34  35-54   55+  \
# 0  1001   alegria-dulantzi    araba/alava   615    250    268   1005   827
# 1  1002            amurrio    araba/alava  1826    588    862   2961  4075
#
#    male  female  total_population
# 0  1525    1440              2965
# 1  5134    5178             10312

# %%
df_demographics = df_demographics[['cmun', '0-17', '18-24',
       '25-34', '35-54', '55+', 'male', 'female', 'total_population']]

# %%
df_municipalities.head(2)
# Out:
#    cmun      municipality   municipality_1 municipality_2 province  \
# 0  1001  Alegría-Dulantzi  alegriadulantzi            NaN    Álava
# 1  1002           Amurrio          amurrio            NaN    Álava
#
#   autonomous_community  latitude  longitude  altitude
# 0           País Vasco  42.84149  -2.513507  561.6857
# 1           País Vasco  43.05265  -3.001022  219.6910

# %%
df_municipalities.columns
# Out:
# Index(['cmun', 'municipality', 'municipality_1', 'municipality_2', 'province',
#        'autonomous_community', 'latitude', 'longitude', 'altitude'],
#       dtype='object')

# %%
df_municipalities = df_municipalities[['cmun', 'municipality', 'province',
       'autonomous_community', 'latitude', 'longitude', 'altitude']]

# %%
df_pueblos = pd.merge(df_municipalities,df_demographics, how="left", on="cmun")
df_pueblos
# Out:
#        cmun                               municipality   province  \
# 0      1001                           Alegría-Dulantzi      Álava
# 1      1002                                    Amurrio      Álava
# 2      1003                                    Aramaio      Álava
# 3      1004                                 Artziniega      Álava
# 4      1006                                    Armiñón      Álava
# ...     ...                                        ...        ...
# 8017  12072                     Llucena/Lucena del Cid  Castellón
# 8018  12901  Alqueries, les/Alquerías del Niño Perdido  Castellón
# 8019  46013                          Alboraia/Alboraya   Valencia
# 8020  46176                            Montroi/Montroy   Valencia
# 8021  46255                      Vilallonga/Villalonga   Valencia
#
#      autonomous_community  latitude  longitude   altitude  0-17  18-24  25-34  \
# 0              País Vasco  42.84149  -2.513507  561.68570   615    250    268
# 1              País Vasco  43.05265  -3.001022  219.69100  1826    588    862
# 2              País Vasco  43.05400  -2.566000  381.87970   218    113    108
# 3              País Vasco  43.12220  -3.128209  196.98080   352    127    146
# 4              País Vasco  42.72305  -2.872574  463.58150    42     20     18
# ...                   ...       ...        ...        ...   ...    ...    ...
# 8017             Valencia  40.13850  -0.279997  564.10640   176     98    137
# 8018             Valencia  39.89653  -0.113446   25.46689   827    327    409
# 8019             Valencia  39.49935  -0.349783   10.95999  4645   2168   2537
# 8020             Valencia  39.34037  -0.614546  142.12200   563    217    394
# 8021             Valencia  38.88487  -0.209364  110.53350   760    339    548
#
#       35-54   55+   male  female  total_population
# 0      1005   827   1525    1440              2965
# 1      2961  4075   5134    5178             10312
# 2       349   592    709     671              1380
# 3       576   655    914     942              1856
# 4        96    70    127     119               246
# ...     ...   ...    ...     ...               ...
# 8017    402   603    709     707              1416
# 8018   1497  1476   2279    2257              4536
# 8019   8575  8334  12719   13540             26259
# 8020   1153  1137   1828    1636              3464
# 8021   1467  1627   2353    2388              4741
#
# [8022 rows x 15 columns]

# %%
df_pueblos = df_pueblos[['cmun', 'municipality', 'province', 'autonomous_community',  'altitude', 'longitude', 'latitude'
       ,'0-17', '18-24', '25-34', '35-54', '55+', 'male', 'female',
       'total_population']]

# %%
df_pueblos.head(2)
# Out:
#    cmun      municipality province autonomous_community  altitude  longitude  \
# 0  1001  Alegría-Dulantzi    Álava           País Vasco  561.6857  -2.513507
# 1  1002           Amurrio    Álava           País Vasco  219.6910  -3.001022
#
#    latitude  0-17  18-24  25-34  35-54   55+  male  female  total_population
# 0  42.84149   615    250    268   1005   827  1525    1440              2965
# 1  43.05265  1826    588    862   2961  4075  5134    5178             10312

# %%
df_pueblos = df_pueblos.merge(df_industry, how="left", on="cmun")

# %%
df_distances.columns
# Out:
# Index(['cmun', 'municipality_name', 'province', 'altitude', 'longitude',
#        'latitude', 'nearest_airport', 'closest_distance_airport',
#        'nearest_train_station', 'closest_distance_train',
#        'closest_distance_hospital', 'nearest_hospital',
#        'closest_distance_school', 'nearest_school'],
#       dtype='object')

# %%
df_distances = df_distances[['cmun', 'nearest_airport', 'closest_distance_airport',
       'nearest_train_station', 'closest_distance_train',
       'closest_distance_hospital', 'nearest_hospital',
       'closest_distance_school', 'nearest_school']]

# %%
df_pueblos = df_pueblos.merge(df_distances, how="left", on="cmun")

# %%
df_climate.columns
# Out:
# Index(['cmun', 'municipality', 'province', 'altitude', 'longitude', 'latitude',
#        'Koppen_Climate', 'description'],
#       dtype='object')

# %%
df_climate = df_climate[['cmun', 'Koppen_Climate', 'description']]

# %%
df_pueblos = df_pueblos.merge(df_climate, how="left", on="cmun")

# %%
df_connectivity = df_connectivity[['cmun', 'number_of_houses', 'VDSL_30Mbps', 'fixed_wireless',
                                    'FTTH', 'HFC', 'reception_30Mbps','reception_100Mbps', 'reception_1Gbps', 
                                    '4G', '5G', '5G_3,5GHz']]

# %%
df_pueblos = df_pueblos.merge(df_connectivity, how="left", on="cmun")

# %%
df_regional_trains = df_regional_trains[["cmun", "count_of_stations", "suburban_train"]]

# %%
df_pueblos = df_pueblos.merge(df_regional_trains, how="left", on="cmun")

# %%
df_pueblos
# Out:
#        cmun                               municipality   province  \
# 0      1001                           Alegría-Dulantzi      Álava
# 1      1002                                    Amurrio      Álava
# 2      1003                                    Aramaio      Álava
# 3      1004                                 Artziniega      Álava
# 4      1006                                    Armiñón      Álava
# ...     ...                                        ...        ...
# 8020  12072                     Llucena/Lucena del Cid  Castellón
# 8021  12901  Alqueries, les/Alquerías del Niño Perdido  Castellón
# 8022  46013                          Alboraia/Alboraya   Valencia
# 8023  46176                            Montroi/Montroy   Valencia
# 8024  46255                      Vilallonga/Villalonga   Valencia
#
#      autonomous_community   altitude  longitude  latitude  0-17  18-24  25-34  \
# 0              País Vasco  561.68570  -2.513507  42.84149   615    250    268
# 1              País Vasco  219.69100  -3.001022  43.05265  1826    588    862
# 2              País Vasco  381.87970  -2.566000  43.05400   218    113    108
# 3              País Vasco  196.98080  -3.128209  43.12220   352    127    146
# 4              País Vasco  463.58150  -2.872574  42.72305    42     20     18
# ...                   ...        ...        ...       ...   ...    ...    ...
# 8020             Valencia  564.10640  -0.279997  40.13850   176     98    137
# 8021             Valencia   25.46689  -0.113446  39.89653   827    327    409
# 8022             Valencia   10.95999  -0.349783  39.49935  4645   2168   2537
# 8023             Valencia  142.12200  -0.614546  39.34037   563    217    394
# 8024             Valencia  110.53350  -0.209364  38.88487   760    339    548
#
#       ...  FTTH   HFC  reception_30Mbps  reception_100Mbps  reception_1Gbps  \
# 0     ...  0.99  0.00              1.00               0.81             0.15
# 1     ...  0.92  0.00              0.93               0.87             0.89
# 2     ...  0.85  0.00              0.89               0.78             0.84
# 3     ...  0.87  0.00              0.98               0.95             0.97
# 4     ...  0.87  0.00              0.99               0.84             0.90
# ...   ...   ...   ...               ...                ...              ...
# 8020  ...  0.88  0.00              0.99               0.89             0.89
# 8021  ...  0.95  0.00              1.00               0.95             0.95
# 8022  ...  0.98  0.71              1.00               0.98             0.98
# 8023  ...  0.52  0.00              1.00               0.37             0.06
# 8024  ...  0.95  0.00              0.94               0.88             0.89
#
#         4G    5G  5G_3,5GHz  count_of_stations  suburban_train
# 0     1.00  0.01        0.0                NaN             NaN
# 1     1.00  0.96        0.0                5.0             1.0
# 2     1.00  0.60        0.0                NaN             NaN
# 3     1.00  0.84        0.0                NaN             NaN
# 4     0.96  0.00        0.0                NaN             NaN
# ...    ...   ...        ...                ...             ...
# 8020  0.98  0.93        0.0                NaN             NaN
# 8021  1.00  0.96        0.0                NaN             NaN
# 8022  1.00  1.00        1.0                2.0             0.0
# 8023  0.98  0.75        0.0                NaN             NaN
# 8024  0.95  0.01        0.0                NaN             NaN
#
# [8025 rows x 46 columns]

# %%
df_pueblos.columns
# Out:
# Index(['cmun', 'municipality', 'province', 'autonomous_community', 'altitude',
#        'longitude', 'latitude', '0-17', '18-24', '25-34', '35-54', '55+',
#        'male', 'female', 'total_population', 'n_industry', 'n_construction',
#        'n_info_communications', 'n_financial_insurance', 'n_real_estate',
#        'n_professional_technical', 'n_eduation_health_social', 'n_other',
#        'nearest_airport', 'closest_distance_airport', 'nearest_train_station',
#        'closest_distance_train', 'closest_distance_hospital',
#        'nearest_hospital', 'closest_distance_school', 'nearest_school',
#        'Koppen_Climate', 'description', 'number_of_houses', 'VDSL_30Mbps',
#        'fixed_wireless', 'FTTH', 'HFC', 'reception_30Mbps',
#        'reception_100Mbps', 'reception_1Gbps', '4G', '5G', '5G_3,5GHz',
#        'count_of_stations', 'suburban_train'],
#       dtype='object')

# %%
df_pueblos = df_pueblos[
    ['cmun', 
     'municipality', 
     'province', 
     'autonomous_community', 
     'altitude',
     'longitude', 
     'latitude', 
     '0-17', 
     '18-24', 
     '25-34', 
     '35-54', 
     '55+',
     'male', 
     'female', 
     'total_population', 
     'n_industry', 
     'n_construction',
     'n_info_communications', 
     'n_financial_insurance', 
     'n_real_estate',
     'n_professional_technical', 
     'n_eduation_health_social', 
     'n_other',
     'nearest_airport', 
     'closest_distance_airport', 
     'nearest_train_station',
     'closest_distance_train', 
     'closest_distance_hospital',
     'nearest_hospital', 
     'closest_distance_school', 
     'nearest_school',
     'Koppen_Climate', 
     'description', 
     'number_of_houses', 
     'VDSL_30Mbps',
     'fixed_wireless', 
     'FTTH', 
     'HFC', 
     'reception_30Mbps',
     'reception_100Mbps', 
     'reception_1Gbps', 
     '4G', 
     '5G', 
     '5G_3,5GHz',
     'count_of_stations', 
     'suburban_train']
]

# %%
df_pueblos.columns = df_pueblos.columns.str.lower().str.replace('_x', '')

# %%
df_pueblos.shape
# Out:
# (8025, 46)

# %%
df_pueblos.to_csv("../data/processed/aggregated_pueblos.csv", index=False)
