# %%
import os
import pandas as pd

processed_dir = '../data/processed'
csv_files = [f for f in os.listdir(processed_dir) if f.endswith('.csv')]

dataframes = {}
for file in csv_files:
    df_name = os.path.splitext(file)[0]
    df_name = "df_" + df_name.split("_")[1]
    df_path = os.path.join(processed_dir, file)
    dataframes[df_name] = pd.read_csv(df_path, encoding="utf-8")
# Display the names of the loaded DataFrames

# %%
# Ensure that df_distances is available from the existing dataframes dictionary.
df_distances = dataframes.get("df_distances")
df_municipalities = dataframes.get("df_municipalities")
df_schools = dataframes.get("df_schools")
df_industry = dataframes.get("df_industry")
df_trains = dataframes.get("df_trains")
df_connectivity = dataframes.get("df_connectivity")
df_climate = dataframes.get("df_climate")
df_airports = dataframes.get("df_airports")
df_demographics = dataframes.get("df_demographics")
df_hospitals = dataframes.get("df_hospitals")

# %%
df_demographics.head()
# Out:
#    cmun municipality_clean province_clean  0-17  18-24  25-34  35-54   55+  \
# 0  1001   alegria-dulantzi    araba/alava   615    250    268   1005   827
# 1  1002            amurrio    araba/alava  1826    588    862   2961  4075
# 2  1003            aramaio    araba/alava   218    113    108    349   592
# 3  1004         artziniega    araba/alava   352    127    146    576   655
# 4  1006            arminon    araba/alava    42     20     18     96    70
#
#    male  female  total_population
# 0  1525    1440              2965
# 1  5134    5178             10312
# 2   709     671              1380
# 3   914     942              1856
# 4   127     119               246

# %%
df_pueblos = pd.merge(df_municipalities,df_demographics, how="left", on="cmun")
df_pueblos
# Out:
#       province      municipality_name municipality_name_clean  \
# 0        Álava       Alegría-Dulantzi        alegria-dulantzi
# 1        Álava                Amurrio                 amurrio
# 2        Álava                Aramaio                 aramaio
# 3        Álava             Artziniega              artziniega
# 4        Álava                Armiñón                 arminon
# ...        ...                    ...                     ...
# 7947  Zaragoza                   Biel                    biel
# 7948  Zaragoza               Marracos                marracos
# 7949  Zaragoza  Villamayor de Gállego   villamayor de gallego
# 7950     Ceuta                  Ceuta                   ceuta
# 7951   Melilla                Melilla                 melilla
#
#      province_clean_x   altitude  longitude  latitude   cmun  \
# 0               alava  561.68570  -2.513507  42.84149   1001
# 1               alava  219.69100  -3.001022  43.05265   1002
# 2               alava  381.87970  -2.566000  43.05400   1003
# 3               alava  196.98080  -3.128209  43.12220   1004
# 4               alava  463.58150  -2.872574  42.72305   1006
# ...               ...        ...        ...       ...    ...
# 7947         zaragoza  754.24450  -0.936588  42.38749  50901
# 7948         zaragoza  404.73610  -0.776047  42.09059  50902
# 7949         zaragoza  231.12340  -0.773315  41.68518  50903
# 7950            ceuta   13.47725  -5.316195  35.88829  51001
# 7951          melilla   10.33370  -2.938794  35.29234  52001
#
#      municipality_clean province_clean_y   0-17  18-24  25-34  35-54    55+  \
# 0      alegria-dulantzi      araba/alava    615    250    268   1005    827
# 1               amurrio      araba/alava   1826    588    862   2961   4075
# 2               aramaio      araba/alava    218    113    108    349    592
# 3            artziniega      araba/alava    352    127    146    576    655
# 4               arminon      araba/alava     42     20     18     96     70
# ...                 ...              ...    ...    ...    ...    ...    ...
# 7947               biel         zaragoza      6      8     16     37    103
# 7948           marracos         zaragoza      4      2      4     33     42
# 7949         villamayor         zaragoza    405    224    320    789   1114
# 7950              ceuta            ceuta  18151   8386  10785  23963  21894
# 7951            melilla          melilla  21086   8706  11696  23407  21090
#
#        male  female  total_population
# 0      1525    1440              2965
# 1      5134    5178             10312
# 2       709     671              1380
# 3       914     942              1856
# 4       127     119               246
# ...     ...     ...               ...
# 7947    104      66               170
# 7948     43      42                85
# 7949   1444    1408              2852
# 7950  41957   41222             83179
# 7951  43252   42733             85985
#
# [7952 rows x 18 columns]

# %%
df_pueblos = df_pueblos.drop(["municipality_name_clean", "province_clean_x", "municipality_clean", "province_clean_y"], axis=1)

# %%
df_pueblos = df_pueblos[['cmun', 'province', 'municipality_name', 'altitude', 'longitude', 'latitude'
       ,'0-17', '18-24', '25-34', '35-54', '55+', 'male', 'female',
       'total_population']]

# %%
df_distances.sample(20)
# Out:
#        cmun      municipality_name     province     altitude  longitude  \
# 4269  28060    Fuentidueña de Tajo       Madrid   565.697800  -3.159549
# 502    5157             Navalacruz        Ávila  1242.845000  -4.932515
# 1015   8178               Rajadell    Barcelona   343.194100   1.706263
# 3917  25208              Soriguera       Lleida  1182.144000   1.181662
# 1668  10154               Rebollar      Cáceres   610.104900  -5.898876
# 6064  42029                Baraona        Soria  1122.398000  -2.657406
# 7850  50201  Paracuellos de Jiloca     Zaragoza   570.923400  -1.639322
# 7255  47183           Valdunquillo   Valladolid   742.070600  -5.315187
# 4021  26052               Cordovín     La Rioja   591.123900  -2.814371
# 7400  48903                   Loiu      Bizkaia    27.390790  -2.938333
# 5632  39005                Argoños    Cantabria     7.686848  -3.485922
# 302    4044                  Fines      Almería   448.701800  -2.262964
# 5897  40198                Sotillo      Segovia   982.981900  -3.637582
# 584    5242             Tiñosillos        Ávila   872.829500  -4.727480
# 4040  26071                   Haro     La Rioja   478.989100  -2.846298
# 5149  34245     Villota del Páramo     Palencia  1001.102000  -4.848131
# 333    4075                  Pulpí      Almería   194.994700  -1.745502
# 2803  19024                Alovera  Guadalajara   648.229600  -3.248165
# 3775  25040               Balaguer       Lleida   227.251300   0.805238
# 2372  16255    Villar de la Encina       Cuenca   843.008400  -2.521609
#
#       latitude                               nearest_airport  \
# 4269  40.11819  Aeropuerto de Adolfo Suárez Madrid - Barajas
# 502   40.44016                      Aeropuerto de Salamanca
# 1015  41.72972                        Aeropuerto de Sabadell
# 3917  42.37069                        Aeropuerto de Sabadell
# 1668  40.15337                      Aeropuerto de Salamanca
# 6064  41.29533  Aeropuerto de Adolfo Suárez Madrid - Barajas
# 7850  41.31345                        Aeropuerto de Zaragoza
# 7255  42.04168                      Aeropuerto de Valladolid
# 4021  42.38482             Aeropuerto de Logroño - Agoncillo
# 7400  43.31500                          Aeropuerto de Bilbao
# 5632  43.45803                    Santander-Seve Ballesteros
# 302   37.35888                         Aeropuerto de Almería
# 5897  41.25824  Aeropuerto de Adolfo Suárez Madrid - Barajas
# 584   40.93408                      Aeropuerto de Salamanca
# 4040  42.57721                         Aeropuerto de Vitoria
# 5149  42.55193                            Aeropuerto de León
# 333   37.41183                         Aeropuerto de Almería
# 2803  40.59670  Aeropuerto de Adolfo Suárez Madrid - Barajas
# 3775  41.78970                            Aeropuerto de Reus
# 2372  39.63701                        Aeropuerto de Albacete
#
#       closest_distance_airport   nearest_train_station  \
# 4269                 54.579928  Santa Cruz De La Zarza
# 502                  74.428124                   Avila
# 1015                 40.501786                Rajadell
# 3917                121.515684         Latour De Carol
# 1668                 94.683518               Plasencia
# 6064                118.123601                Torralba
# 7850                 62.533723               Calatayud
# 7255                 53.550203                 Villada
# 4021                 41.745820                    Haro
# 7400                  2.800147      Nanclares-Langraiz
# 5632                 27.501951      Nanclares-Langraiz
# 302                  57.860516                  Gergal
# 5897                 85.239815                 Segovia
# 584                  65.327541                 Arevalo
# 4040                 34.842985                    Haro
# 5149                 66.338270                 Sahagun
# 333                  83.976289               Cartagena
# 2803                 30.128465       Guadalajara-Yebes
# 3775                 77.292026      Bell-Lloc D'Urgell
# 2372                 95.131987           Villarrobledo
#
#       closest_distance_train  closest_distance_hospital  \
# 4269               16.233268                  32.162554
# 502                32.038313                  30.907570
# 1015                0.699338                   8.787457
# 3917               60.298842                  23.055022
# 1668               22.466550                  19.705417
# 6064               22.419870                  55.073134
# 7850                3.689443                   2.551832
# 7255               36.371730                  30.256483
# 4021               22.271701                  25.685535
# 7400               56.465211                   2.363760
# 5632               90.295777                   6.053864
# 302                40.247449                  28.824204
# 5897               53.792045                  45.865896
# 584                12.736064                  29.961650
# 4040                0.755466                  15.597268
# 5149               24.848602                  41.751551
# 333                71.418770                  17.423171
# 2803               10.475118                   7.072758
# 3775               17.663793                  23.830120
# 2372               42.284545                  40.237255
#
#                                 nearest_hospital  closest_distance_school  \
# 4269          Hospital Universitario Del Sureste                 0.183506
# 502                 Hospital Provincial De Ávila                 4.377586
# 1015  Serveis Sanitaris Sant Joan De Vilatorrada                 4.633151
# 3917                     Fundació Sant Hospital.                 6.148473
# 1668                  Hospital Virgen Del Puerto                 0.067289
# 6064               Complejo Asistencial De Soria                21.941496
# 7850                Hospital Ernest Lluch Martin                 2.056990
# 7255                       Hospital De Benavente                 9.352907
# 4021                            Hospital De Leza                 1.901939
# 7400                Hospital Quironsalud Bizkaia                 0.803761
# 5632                 Hospital Comarcal De Laredo                23.185383
# 302                       Hospital La Inmaculada                 0.329924
# 5897                       Hospital Santos Reyes                 8.699580
# 584                Complejo Asistencial De Avila                 5.995997
# 4040                   Hospital Santiago Apóstol                 0.414695
# 5149                            Hospital De León                 6.408746
# 333                       Hospital La Inmaculada                 1.090373
# 2803                          Clínica La Antigua                 3.550226
# 3775                    Clínica Terres De Ponent                 0.046563
# 2372            Hospital General De Villarobledo                18.183333
#
#                                      nearest_school
# 4269                            EEI-CN La Ballenita
# 502                               Cra Alto Alberche
# 1015                          Llar d'infants Rexics
# 3917               Llar d'infants Municipal de Sort
# 1668                          C.R.A. Tras la Sierra
# 6064                                        Almazán
# 7850                               Baltasar Graci�n
# 7255                    Cra De Villanueva Del Campo
# 4021              C.R.A. Entrevalles (Base-Badarán)
# 7400                         Zabaloetxe Goikoa Hbip
# 5632           Escuela municipal de teatro La Villa
# 302                      C.E.I.P. Rafaela Fernández
# 5897                              Cardenal Cisneros
# 584                               Cra Los Regajales
# 4040                C.E.I.P. San Felices de Bibilio
# 5149                      Padre Anastasio Gutiérrez
# 333                    C.E.I.P. Emilio Zurano Muñoz
# 2803                                 CEIP La Espiga
# 3775                                   CFA Balaguer
# 2372  Colegio Público Fray Luis de León  (año 1916)

# %%
df_pueblos = df_pueblos.merge(df_industry, how="left", on="cmun")
df_pueblos = df_pueblos.merge(df_distances, how="left", on="cmun")
df_pueblos = df_pueblos.merge(df_climate, how="left", on="cmun")
df_pueblos = df_pueblos.merge(df_connectivity, how="left", on="cmun")

# %%
df_pueblos
# Out:
#        cmun province_x    municipality_name_x  altitude_x  longitude_x  \
# 0      1001      Álava       Alegría-Dulantzi   561.68570    -2.513507
# 1      1002      Álava                Amurrio   219.69100    -3.001022
# 2      1003      Álava                Aramaio   381.87970    -2.566000
# 3      1004      Álava             Artziniega   196.98080    -3.128209
# 4      1006      Álava                Armiñón   463.58150    -2.872574
# ...     ...        ...                    ...         ...          ...
# 7953  50901   Zaragoza                   Biel   754.24450    -0.936588
# 7954  50902   Zaragoza               Marracos   404.73610    -0.776047
# 7955  50903   Zaragoza  Villamayor de Gállego   231.12340    -0.773315
# 7956  51001      Ceuta                  Ceuta    13.47725    -5.316195
# 7957  52001    Melilla                Melilla    10.33370    -2.938794
#
#       latitude_x   0-17  18-24  25-34  35-54  ...  VDSL_30Mbps  \
# 0       42.84149    615    250    268   1005  ...         0.29
# 1       43.05265   1826    588    862   2961  ...         0.10
# 2       43.05400    218    113    108    349  ...         0.21
# 3       43.12220    352    127    146    576  ...         0.11
# 4       42.72305     42     20     18     96  ...         0.00
# ...          ...    ...    ...    ...    ...  ...          ...
# 7953    42.38749      6      8     16     37  ...         0.00
# 7954    42.09059      4      2      4     33  ...         0.00
# 7955    41.68518    405    224    320    789  ...         0.00
# 7956    35.88829  18151   8386  10785  23963  ...         0.23
# 7957    35.29234  21086   8706  11696  23407  ...         0.11
#
#       fixed_wireless  FTTH  HFC  reception_30Mbps  reception_100Mbps  \
# 0               1.00  0.99  0.0              1.00               0.81
# 1               1.00  0.92  0.0              0.93               0.87
# 2               0.94  0.85  0.0              0.89               0.78
# 3               1.00  0.87  0.0              0.98               0.95
# 4               0.53  0.87  0.0              0.99               0.84
# ...              ...   ...  ...               ...                ...
# 7953            1.00  0.78  0.0              1.00               0.46
# 7954            0.95  0.00  0.0              0.99               0.00
# 7955            1.00  0.76  0.0              1.00               0.77
# 7956            1.00  0.99  0.0              1.00               0.99
# 7957            0.99  0.99  0.0              1.00               1.00
#
#       reception_1Gbps    4G    5G  5G_3,5GHz
# 0                0.15  1.00  0.01       0.00
# 1                0.89  1.00  0.96       0.00
# 2                0.84  1.00  0.60       0.00
# 3                0.97  1.00  0.84       0.00
# 4                0.90  0.96  0.00       0.00
# ...               ...   ...   ...        ...
# 7953             0.00  0.85  0.00       0.00
# 7954             0.00  0.39  0.00       0.00
# 7955             0.71  1.00  0.99       0.05
# 7956             0.98  1.00  0.99       0.77
# 7957             0.99  1.00  1.00       0.09
#
# [7958 rows x 54 columns]

# %%
df_pueblos.columns
# Out:
# Index(['cmun', 'province_x', 'municipality_name_x', 'altitude_x',
#        'longitude_x', 'latitude_x', '0-17', '18-24', '25-34', '35-54', '55+',
#        'male', 'female', 'total_population', 'n_industry', 'n_construction',
#        'n_info_communications', 'n_financial_insurance', 'n_real_estate',
#        'n_professional_technical', 'n_eduation_health_social', 'n_other',
#        'municipality_name_y', 'province_y', 'altitude_y', 'longitude_y',
#        'latitude_y', 'nearest_airport', 'closest_distance_airport',
#        'nearest_train_station', 'closest_distance_train',
#        'closest_distance_hospital', 'nearest_hospital',
#        'closest_distance_school', 'nearest_school', 'municipality_x',
#        'province', 'altitude', 'longitude', 'latitude', 'Koppen_Climate',
#        'description', 'municipality_y', 'number_of_houses', 'VDSL_30Mbps',
#        'fixed_wireless', 'FTTH', 'HFC', 'reception_30Mbps',
#        'reception_100Mbps', 'reception_1Gbps', '4G', '5G', '5G_3,5GHz'],
#       dtype='object')

# %%
df_pueblos = df_pueblos[
    [
        'cmun',
        'province_x',
        'municipality_x',,
        'altitude',
        'longitude',
        'latitude',
        '0-17',
        '18-24',
        '25-34',
        '35-54',
        '55+',
        'male',
        'female',
        'total_population',
        'n_industry',
        'n_construction',
        'n_info_communications',
        'n_financial_insurance',
        'n_real_estate',
        'n_professional_technical',
        'n_eduation_health_social',
        'n_other',
        'nearest_airport',
        'closest_distance_airport',
        'nearest_train_station',
        'closest_distance_train',
        'closest_distance_hospital',
        'nearest_hospital',
        'closest_distance_school',
        'nearest_school',
        'Koppen_Climate',
        'description',
        'number_of_houses',
        'VDSL_30Mbps',
        'fixed_wireless',
        'FTTH',
        'HFC',
        'reception_30Mbps',
        'reception_100Mbps',
        'reception_1Gbps',
        '4G',
        '5G',
        '5G_3,5GHz'
    ]
]

# %%
df_pueblos.columns = df_pueblos.columns.str.lower().str.replace('_x', '')

# %%
df_pueblos
# Out:
#        cmun  province      municipality_name   altitude  longitude  latitude  \
# 0      1001     Álava       Alegría-Dulantzi  561.68570  -2.513507  42.84149
# 1      1002     Álava                Amurrio  219.69100  -3.001022  43.05265
# 2      1003     Álava                Aramaio  381.87970  -2.566000  43.05400
# 3      1004     Álava             Artziniega  196.98080  -3.128209  43.12220
# 4      1006     Álava                Armiñón  463.58150  -2.872574  42.72305
# ...     ...       ...                    ...        ...        ...       ...
# 7953  50901  Zaragoza                   Biel  754.24450  -0.936588  42.38749
# 7954  50902  Zaragoza               Marracos  404.73610  -0.776047  42.09059
# 7955  50903  Zaragoza  Villamayor de Gállego  231.12340  -0.773315  41.68518
# 7956  51001     Ceuta                  Ceuta   13.47725  -5.316195  35.88829
# 7957  52001   Melilla                Melilla   10.33370  -2.938794  35.29234
#
#        0-17  18-24  25-34  35-54  ...  vdsl_30mbps  fixed_wireless  ftth  hfc  \
# 0       615    250    268   1005  ...         0.29            1.00  0.99  0.0
# 1      1826    588    862   2961  ...         0.10            1.00  0.92  0.0
# 2       218    113    108    349  ...         0.21            0.94  0.85  0.0
# 3       352    127    146    576  ...         0.11            1.00  0.87  0.0
# 4        42     20     18     96  ...         0.00            0.53  0.87  0.0
# ...     ...    ...    ...    ...  ...          ...             ...   ...  ...
# 7953      6      8     16     37  ...         0.00            1.00  0.78  0.0
# 7954      4      2      4     33  ...         0.00            0.95  0.00  0.0
# 7955    405    224    320    789  ...         0.00            1.00  0.76  0.0
# 7956  18151   8386  10785  23963  ...         0.23            1.00  0.99  0.0
# 7957  21086   8706  11696  23407  ...         0.11            0.99  0.99  0.0
#
#       reception_30mbps  reception_100mbps  reception_1gbps    4g    5g  \
# 0                 1.00               0.81             0.15  1.00  0.01
# 1                 0.93               0.87             0.89  1.00  0.96
# 2                 0.89               0.78             0.84  1.00  0.60
# 3                 0.98               0.95             0.97  1.00  0.84
# 4                 0.99               0.84             0.90  0.96  0.00
# ...                ...                ...              ...   ...   ...
# 7953              1.00               0.46             0.00  0.85  0.00
# 7954              0.99               0.00             0.00  0.39  0.00
# 7955              1.00               0.77             0.71  1.00  0.99
# 7956              1.00               0.99             0.98  1.00  0.99
# 7957              1.00               1.00             0.99  1.00  1.00
#
#       5g_3,5ghz
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
# ...         ...
# 7953       0.00
# 7954       0.00
# 7955       0.05
# 7956       0.77
# 7957       0.09
#
# [7958 rows x 54 columns]
