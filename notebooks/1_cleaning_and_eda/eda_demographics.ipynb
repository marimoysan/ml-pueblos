# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
import pandas as pd
from unidecode import unidecode

# %% [markdown]
# # First Part: Data Cleanup

# %%
df_raw = pd.read_csv("../../data/raw/68542.csv", sep=";", decimal=",")

# %%
df_raw.head()
# Out:
#    National Total Provinces Municipalities    Sex          Age  Periodo  \
# 0  National Total       NaN            NaN  Males     All ages     2024
# 1  National Total       NaN            NaN  Males     All ages     2023
# 2  National Total       NaN            NaN  Males     All ages     2022
# 3  National Total       NaN            NaN  Males     All ages     2021
# 4  National Total       NaN            NaN  Males  0 years old     2024
#
#         Total
# 0  23.826.871
# 1  23.565.593
# 2  23.288.747
# 3  23.248.611
# 4     164.763

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10018440 entries, 0 to 10018439
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   National Total  object
#  1   Provinces       object
#  2   Municipalities  object
#  3   Sex             object
#  4   Age             object
#  5   Periodo         int64
#  6   Total           object
# dtypes: int64(1), object(6)
# memory usage: 535.0+ MB

# %%
df_raw.sample(15)
# Out:
#          National Total              Provinces  \
# 1379662  National Total           08 Barcelona
# 3167723  National Total              17 Girona
# 7124835  National Total           39 Cantabria
# 6797012  National Total           37 Salamanca
# 870810   National Total             06 Badajoz
# 6309311  National Total            34 Palencia
# 5728617  National Total             31 Navarra
# 5050420  National Total           26 Rioja, La
# 9799698  National Total            50 Zaragoza
# 6941351  National Total           37 Salamanca
# 820451   National Total             06 Badajoz
# 6007081  National Total             31 Navarra
# 7003910  National Total           37 Salamanca
# 2315922  National Total  12 Castellón/Castelló
# 6416675  National Total            34 Palencia
#
#                             Municipalities      Sex                Age  \
# 1379662  08259 Santa Maria de Palautordera    Males       52 years old
# 3167723            17123 Palol de Revardit    Males         1 year old
# 7124835              39020 Castro-Urdiales    Total       83 years old
# 6797012    37185 Castellanos de Villiquera    Males       34 years old
# 870810                      06075 Magacela  Females       33 years old
# 6309311         34077 Fuentes de Valdepero  Females  100 years or more
# 5728617                     31032 Arguedas    Males       73 years old
# 5050420                      26051 Clavijo    Males       48 years old
# 9799698                       50123 Grisén    Males       87 years old
# 6941351         37307 Serradilla del Llano    Males       10 years old
# 820451                06034 Casas de Reina    Males       91 years old
# 6007081       31260 Valle de Yerri/Deierri    Total       23 years old
# 7003910          37360 Villar de Peralonso    Males       44 years old
# 2315922                        12076 Matet    Males       27 years old
# 6416675             34196 Valle de Cerrato  Females       13 years old
#
#          Periodo Total
# 1379662     2022    69
# 3167723     2021     2
# 7124835     2021   137
# 6797012     2024     3
# 870810      2022     4
# 6309311     2021     0
# 5728617     2023    16
# 5050420     2024     4
# 9799698     2022     1
# 6941351     2021     0
# 820451      2021     0
# 6007081     2023    15
# 7003910     2022     0
# 2315922     2022     2
# 6416675     2021     0

# %%
df_raw.drop(columns=['National Total'], inplace=True)

# %%
df_raw.isnull().sum()
# Out:
# Provinces          1224
# Municipalities    64872
# Sex                   0
# Age                   0
# Periodo               0
# Total               918
# dtype: int64

# %%
df_municipalities_null = df_raw[df_raw['Municipalities'].isnull()]
df_municipalities_null[df_municipalities_null["Provinces"] == "08 Barcelona"]
# Out:
#             Provinces Municipalities    Sex                Age  Periodo  \
# 1064880  08 Barcelona            NaN  Males           All ages     2024
# 1064881  08 Barcelona            NaN  Males           All ages     2023
# 1064882  08 Barcelona            NaN  Males           All ages     2022
# 1064883  08 Barcelona            NaN  Males           All ages     2021
# 1064884  08 Barcelona            NaN  Males        0 years old     2024
# ...               ...            ...    ...                ...      ...
# 1066099  08 Barcelona            NaN  Total       99 years old     2021
# 1066100  08 Barcelona            NaN  Total  100 years or more     2024
# 1066101  08 Barcelona            NaN  Total  100 years or more     2023
# 1066102  08 Barcelona            NaN  Total  100 years or more     2022
# 1066103  08 Barcelona            NaN  Total  100 years or more     2021
#
#              Total
# 1064880  2.870.721
# 1064881  2.830.260
# 1064882  2.783.698
# 1064883  2.785.890
# 1064884     20.185
# ...            ...
# 1066099      1.096
# 1066100      1.982
# 1066101      1.807
# 1066102      1.707
# 1066103      1.546
#
# [1224 rows x 6 columns]

# %% [markdown]
# ### We have information about provinces without the municipalities, we should drop them

# %%
df_raw[df_raw['Provinces'] == "25 Lleida"].sample(5)
# Out:
#          Provinces           Municipalities      Sex           Age  Periodo  \
# 4768310  25 Lleida             25056 Bovera    Total   2 years old     2022
# 4889343  25 Lleida  25173 Pont de Suert, El  Females  68 years old     2021
# 4803861  25 Lleida       25092 Floresta, La    Total  16 years old     2023
# 4840274  25 Lleida           25128 Llimiana  Females  41 years old     2022
# 4840026  25 Lleida           25128 Llimiana    Males  81 years old     2022
#
#         Total
# 4768310     2
# 4889343    14
# 4803861     1
# 4840274     0
# 4840026     1

# %%
prov_null = df_raw[["Provinces", "Municipalities"]]

prov_null[(prov_null["Provinces"].isnull()) & (prov_null["Municipalities"].isnull())]
# Out:
#      Provinces Municipalities
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# ...        ...            ...
# 1219       NaN            NaN
# 1220       NaN            NaN
# 1221       NaN            NaN
# 1222       NaN            NaN
# 1223       NaN            NaN
#
# [1224 rows x 2 columns]

# %%
prov_null[(prov_null["Provinces"].isnull())]
# Out:
#      Provinces Municipalities
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# ...        ...            ...
# 1219       NaN            NaN
# 1220       NaN            NaN
# 1221       NaN            NaN
# 1222       NaN            NaN
# 1223       NaN            NaN
#
# [1224 rows x 2 columns]

# %%
df_raw[df_raw['Total'].isnull()].sample(5)
# Out:
#           Provinces Municipalities      Sex           Age  Periodo Total
# 9348774  48 Bizkaia       48916 NA    Total  66 years old     2022   NaN
# 9348719  48 Bizkaia       48916 NA    Total  52 years old     2021   NaN
# 9348763  48 Bizkaia       48916 NA    Total  63 years old     2021   NaN
# 9348099  48 Bizkaia       48916 NA  Females      All ages     2021   NaN
# 9347957  48 Bizkaia       48916 NA    Males  66 years old     2023   NaN
# 9347937  48 Bizkaia       48916 NA    Males  61 years old     2023   NaN
# 9348513  48 Bizkaia       48916 NA    Total    1 year old     2023   NaN
# 9348669  48 Bizkaia       48916 NA    Total  40 years old     2023   NaN
# 9348529  48 Bizkaia       48916 NA    Total   5 years old     2023   NaN
# 9348409  48 Bizkaia       48916 NA  Females  77 years old     2023   NaN
# 9348069  48 Bizkaia       48916 NA    Males  94 years old     2023   NaN
# 9348127  48 Bizkaia       48916 NA  Females   6 years old     2021   NaN
# 9348747  48 Bizkaia       48916 NA    Total  59 years old     2021   NaN
# 9348318  48 Bizkaia       48916 NA  Females  54 years old     2022   NaN
# 9348174  48 Bizkaia       48916 NA  Females  18 years old     2022   NaN
# 9348667  48 Bizkaia       48916 NA    Total  39 years old     2021   NaN
# 9348895  48 Bizkaia       48916 NA    Total  96 years old     2021   NaN
# 9348402  48 Bizkaia       48916 NA  Females  75 years old     2022   NaN
# 9347858  48 Bizkaia       48916 NA    Males  41 years old     2022   NaN
# 9348018  48 Bizkaia       48916 NA    Males  81 years old     2022   NaN
# 9348418  48 Bizkaia       48916 NA  Females  79 years old     2022   NaN
# 9348675  48 Bizkaia       48916 NA    Total  41 years old     2021   NaN
# 9347771  48 Bizkaia       48916 NA    Males  19 years old     2021   NaN
# 9347695  48 Bizkaia       48916 NA    Males   0 years old     2021   NaN
# 9348711  48 Bizkaia       48916 NA    Total  50 years old     2021   NaN
# 9347703  48 Bizkaia       48916 NA    Males   2 years old     2021   NaN
# 9348802  48 Bizkaia       48916 NA    Total  73 years old     2022   NaN
# 9347793  48 Bizkaia       48916 NA    Males  25 years old     2023   NaN
# 9348487  48 Bizkaia       48916 NA  Females  96 years old     2021   NaN
# 9348173  48 Bizkaia       48916 NA  Females  18 years old     2023   NaN

# %%
df_raw.sample(20)
# Out:
#                     Provinces                  Municipalities      Sex  \
# 3940553           20 Gipuzkoa                     20059 Oñati  Females
# 8030293          43 Tarragona               43157 Ulldemolins    Total
# 5023298          26 Rioja, La        26029 Bergasillas Bajera    Males
# 6694897          37 Salamanca                    37098 Cepeda    Total
# 2769998             16 Cuenca    16030 Bascuñana de San Pedro    Males
# 479118               05 Ávila  05007 Aldeanueva de Santa Cruz  Females
# 2152199            10 Cáceres       10205 Valverde del Fresno    Males
# 1542565             09 Burgos         09095 Celada del Camino    Males
# 6730683          37 Salamanca        37129 Florida de Liébana    Total
# 257827    03 Alicante/Alacant                 03069 Finestrat  Females
# 8787200  46 Valencia/València                46148 Loriguilla    Males
# 1485231             09 Burgos    09038 Barbadillo del Mercado  Females
# 8756858  46 Valencia/València                    46123 Favara    Males
# 3469496            18 Granada                    18170 Rubite  Females
# 6421508           34 Palencia              34204 Villacidaler    Males
# 7180074          39 Cantabria                    39066 Ruente    Males
# 9061418         47 Valladolid         47106 Olmos de Peñafiel    Males
# 8928755  46 Valencia/València                     46263 Zarra    Total
# 9527614             49 Zamora                49158 Piñero, El    Total
# 3955625           20 Gipuzkoa                    20071 Tolosa    Total
#
#                        Age  Periodo Total
# 3940553       21 years old     2023    56
# 8030293        8 years old     2023     5
# 5023298           All ages     2022    19
# 6694897        5 years old     2023     1
# 2769998       20 years old     2022     0
# 479118        30 years old     2022     0
# 2152199  100 years or more     2021     1
# 1542565       80 years old     2023     0
# 6730683       77 years old     2021     0
# 257827        93 years old     2021     1
# 8787200       25 years old     2024    15
# 1485231       26 years old     2021     3
# 8756858       89 years old     2022     4
# 3469496       67 years old     2024     5
# 6421508  100 years or more     2024     0
# 7180074       21 years old     2022     5
# 9061418       35 years old     2022     1
# 8928755       19 years old     2021     3
# 9527614  100 years or more     2022     0
# 3955625       15 years old     2023   186

# %%
df_raw = df_raw.dropna(subset=["Provinces", "Municipalities", "Total"], how="any")

# %%
df_2024 = df_raw[df_raw['Periodo'] == 2024].copy()

# %%
df_2024.reset_index(drop=True, inplace=True)

# %%
idx = pd.Index(["Provinces", "Municipalities", "Sex", "Age", "Periodo", "Total"])
eng = pd.Index(["province", "municipality", "sex", "age", "year", "total"])

df_2024.rename(columns=dict(zip(idx, eng)), inplace=True)

# %% [markdown]
# ### Get the correct types

# %%
df_2024["total"] = pd.to_numeric(df_2024["total"].str.replace(".", "", regex=False)).astype("int32")

# %%
df_2024 = df_2024[df_2024["age"] != "All ages"]

# %%
(df_2024["age"].str.contains(r"^\d"))
# Out:
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
#            ...
# 2488387    True
# 2488388    True
# 2488389    True
# 2488390    True
# 2488391    True
# Name: age, Length: 2463996, dtype: bool

# %%
df_2024.head()
# Out:
#          province            municipality    sex          age  year  total
# 1  01 Araba/Álava  01001 Alegría-Dulantzi  Males  0 years old  2024     11
# 2  01 Araba/Álava  01001 Alegría-Dulantzi  Males   1 year old  2024      9
# 3  01 Araba/Álava  01001 Alegría-Dulantzi  Males  2 years old  2024     15
# 4  01 Araba/Álava  01001 Alegría-Dulantzi  Males  3 years old  2024     12
# 5  01 Araba/Álava  01001 Alegría-Dulantzi  Males  4 years old  2024      9

# %%
df_2024["province"] = df_2024["province"].astype(str)
df_2024["municipality"] = df_2024["municipality"].astype(str)
df_2024["age"] = df_2024["age"].astype(str)

# %%
df_2024["age"] = df_2024["age"].str.extract(r"(\d+)").astype(float).astype("Int64")

# %%
df_2024[["cprov", "province_name"]] = df_2024["province"].str.split(" ", n=1, expand=True)
df_2024[["cmun", "municipality_name"]] = df_2024["municipality"].str.split(" ", n=1, expand=True)
df_2024.drop(columns=["province", "municipality"], inplace=True)

# %%
df_2024
# Out:
#            sex  age  year  total cprov province_name   cmun municipality_name
# 1        Males    0  2024     11    01   Araba/Álava  01001  Alegría-Dulantzi
# 2        Males    1  2024      9    01   Araba/Álava  01001  Alegría-Dulantzi
# 3        Males    2  2024     15    01   Araba/Álava  01001  Alegría-Dulantzi
# 4        Males    3  2024     12    01   Araba/Álava  01001  Alegría-Dulantzi
# 5        Males    4  2024      9    01   Araba/Álava  01001  Alegría-Dulantzi
# ...        ...  ...   ...    ...   ...           ...    ...               ...
# 2488387  Total   96  2024     19    52       Melilla  52001           Melilla
# 2488388  Total   97  2024     13    52       Melilla  52001           Melilla
# 2488389  Total   98  2024     11    52       Melilla  52001           Melilla
# 2488390  Total   99  2024      3    52       Melilla  52001           Melilla
# 2488391  Total  100  2024     12    52       Melilla  52001           Melilla
#
# [2463996 rows x 8 columns]

# %%
df_2024.drop("cprov", axis = 1, inplace=True)

# %%
# Function to clean a column (remove accents, normalize case)
def clean_column(column):
    return column.apply(lambda x: unidecode(str(x)).strip().lower() if pd.notna(x) else x)

# Apply cleaning to df_municipalities
df_2024["municipality_clean"] = clean_column(df_2024["municipality_name"])
df_2024["province_clean"] = clean_column(df_2024["municipality_name"])

# %%
df_2024.sample(5)
# Out:
#              sex  age  year  total           province_name   cmun  \
# 1686933    Total   56  2024      2               Salamanca  37182
# 1757160  Females    5  2024     34  Santa Cruz de Tenerife  38036
# 884370     Males   29  2024      0             Guadalajara  19047
# 2141671    Total   78  2024     33       Valencia/València  46014
# 1867905    Males   80  2024     21                 Sevilla  41033
#
#                   municipality_name          municipality_clean  \
# 1686933                  Martinamor                  martinamor
# 1757160  San Sebastián de la Gomera  san sebastian de la gomera
# 884370                       Baides                      baides
# 2141671                   Albuixech                   albuixech
# 1867905                 Constantina                 constantina
#
#                      province_clean
# 1686933                  martinamor
# 1757160  san sebastian de la gomera
# 884370                       baides
# 2141671                   albuixech
# 1867905                 constantina

# %%
df_2024.to_csv("../../data/large_files/filtered_age.csv", index=False)

# %% [markdown]
# # Second Part: Binning and Pivoting

# %%
df_ages_bined = pd.read_csv("../../data/large_files/filtered_age.csv")

df_ages_bined.shape
df_ages_bined.head()
# Out:
#      sex  age  year  total province_name  cmun municipality_name  \
# 0  Males    0  2024     11   Araba/Álava  1001  Alegría-Dulantzi
# 1  Males    1  2024      9   Araba/Álava  1001  Alegría-Dulantzi
# 2  Males    2  2024     15   Araba/Álava  1001  Alegría-Dulantzi
# 3  Males    3  2024     12   Araba/Álava  1001  Alegría-Dulantzi
# 4  Males    4  2024      9   Araba/Álava  1001  Alegría-Dulantzi
#
#   municipality_clean    province_clean
# 0   alegria-dulantzi  alegria-dulantzi
# 1   alegria-dulantzi  alegria-dulantzi
# 2   alegria-dulantzi  alegria-dulantzi
# 3   alegria-dulantzi  alegria-dulantzi
# 4   alegria-dulantzi  alegria-dulantzi

# %%
df_demographics = df_ages_bined.query("sex != 'Total'")

# %%
df_demographics.isna().sum()
# Out:
# sex                     0
# age                     0
# year                    0
# total                   0
# province_name           0
# cmun                    0
# municipality_name     202
# municipality_clean      0
# province_clean          0
# dtype: int64

# %%
def assign_age_group(age):
    if age <= 17:
        return '0-17'
    elif age <= 24:
        return '18-24'
    elif age <= 34:
        return '25-34'
    elif age <= 54:
        return '35-54'
    else:
        return '55+'

df_demographics['age_group'] = df_demographics['age'].apply(assign_age_group)
# Out:
# C:\Users\Marina\AppData\Local\Temp\ipykernel_13268\3734956762.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_demographics['age_group'] = df_demographics['age'].apply(assign_age_group)

# %%
df_demographics["age_group"].unique()
# Out:
# array(['0-17', '18-24', '25-34', '35-54', '55+'], dtype=object)

# %%
# 2. Pivot the table to have one column per age group
#    We group by 'cmun' (or whichever municipality identifier you prefer)
pivot_df = df_demographics.pivot_table(
    index='cmun',
    columns='age_group',
    values='total',
    aggfunc='sum',
    fill_value=0  # fill missing combinations with 0
).reset_index()

# %%
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
pivot_df = pivot_df[['cmun'] + [grp for grp in age_group_order if grp in pivot_df.columns]]
pivot_df["total_population"] = pivot_df["0-17"] + pivot_df["18-24"] + pivot_df["25-34"] + pivot_df["35-54"] + pivot_df["55+"]

pivot_df
# Out:
# age_group   cmun   0-17  18-24  25-34  35-54    55+  total_population
# 0           1001    615    250    268   1005    827              2965
# 1           1002   1826    588    862   2961   4075             10312
# 2           1003    218    113    108    349    592              1380
# 3           1004    352    127    146    576    655              1856
# 4           1006     42     20     18     96     70               246
# ...          ...    ...    ...    ...    ...    ...               ...
# 8127       50901      6      8     16     37    103               170
# 8128       50902      4      2      4     33     42                85
# 8129       50903    405    224    320    789   1114              2852
# 8130       51001  18151   8386  10785  23963  21894             83179
# 8131       52001  21086   8706  11696  23407  21090             85985
#
# [8132 rows x 7 columns]

# %%
pivot_df_sex = df_demographics.pivot_table(
    index='cmun',
    columns='sex',
    values='total',
    aggfunc='sum',
    fill_value=0  # fill missing combinations with 0
).reset_index()

# %%
df_demographics["sex"].unique()
# Out:
# array(['Males', 'Females'], dtype=object)

# %%
sex_group_order = ['Males', 'Females']

pivot_df_sex = pivot_df_sex[['cmun'] + [grp for grp in sex_group_order if grp in pivot_df_sex.columns]]
pivot_df_sex.rename(columns={"Males": "male", "Females": "female"}, inplace=True)

pivot_df_sex["total_sex"] = pivot_df_sex["male"] + pivot_df_sex["female"]
pivot_df_sex
# Out:
# sex    cmun   male  female  total_sex
# 0      1001   1525    1440       2965
# 1      1002   5134    5178      10312
# 2      1003    709     671       1380
# 3      1004    914     942       1856
# 4      1006    127     119        246
# ...     ...    ...     ...        ...
# 8127  50901    104      66        170
# 8128  50902     43      42         85
# 8129  50903   1444    1408       2852
# 8130  51001  41957   41222      83179
# 8131  52001  43252   42733      85985
#
# [8132 rows x 4 columns]

# %%
df_demographics_combined = pivot_df.merge(df_demographics, on='cmun', how='left')
df_demographics_combined = pivot_df_sex.merge(df_demographics_combined, on='cmun', how='left')

df_demographics_combined
# Out:
#           cmun   male  female  total_sex   0-17  18-24  25-34  35-54    55+  \
# 0         1001   1525    1440       2965    615    250    268   1005    827
# 1         1001   1525    1440       2965    615    250    268   1005    827
# 2         1001   1525    1440       2965    615    250    268   1005    827
# 3         1001   1525    1440       2965    615    250    268   1005    827
# 4         1001   1525    1440       2965    615    250    268   1005    827
# ...        ...    ...     ...        ...    ...    ...    ...    ...    ...
# 1642659  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642660  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642661  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642662  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642663  52001  43252   42733      85985  21086   8706  11696  23407  21090
#
#          total_population      sex  age  year  total province_name  \
# 0                    2965    Males    0  2024     11   Araba/Álava
# 1                    2965    Males    1  2024      9   Araba/Álava
# 2                    2965    Males    2  2024     15   Araba/Álava
# 3                    2965    Males    3  2024     12   Araba/Álava
# 4                    2965    Males    4  2024      9   Araba/Álava
# ...                   ...      ...  ...   ...    ...           ...
# 1642659             85985  Females   96  2024     10       Melilla
# 1642660             85985  Females   97  2024     11       Melilla
# 1642661             85985  Females   98  2024      9       Melilla
# 1642662             85985  Females   99  2024      1       Melilla
# 1642663             85985  Females  100  2024     12       Melilla
#
#         municipality_name municipality_clean    province_clean age_group
# 0        Alegría-Dulantzi   alegria-dulantzi  alegria-dulantzi      0-17
# 1        Alegría-Dulantzi   alegria-dulantzi  alegria-dulantzi      0-17
# 2        Alegría-Dulantzi   alegria-dulantzi  alegria-dulantzi      0-17
# 3        Alegría-Dulantzi   alegria-dulantzi  alegria-dulantzi      0-17
# 4        Alegría-Dulantzi   alegria-dulantzi  alegria-dulantzi      0-17
# ...                   ...                ...               ...       ...
# 1642659           Melilla            melilla           melilla       55+
# 1642660           Melilla            melilla           melilla       55+
# 1642661           Melilla            melilla           melilla       55+
# 1642662           Melilla            melilla           melilla       55+
# 1642663           Melilla            melilla           melilla       55+
#
# [1642664 rows x 19 columns]

# %%
df_demographics_combined = df_demographics_combined.drop(["year", "municipality_name", "province_name", "total_sex"], axis = 1)

# %%
df_demographics_combined
# Out:
#           cmun   male  female   0-17  18-24  25-34  35-54    55+  \
# 0         1001   1525    1440    615    250    268   1005    827
# 1         1001   1525    1440    615    250    268   1005    827
# 2         1001   1525    1440    615    250    268   1005    827
# 3         1001   1525    1440    615    250    268   1005    827
# 4         1001   1525    1440    615    250    268   1005    827
# ...        ...    ...     ...    ...    ...    ...    ...    ...
# 1642659  52001  43252   42733  21086   8706  11696  23407  21090
# 1642660  52001  43252   42733  21086   8706  11696  23407  21090
# 1642661  52001  43252   42733  21086   8706  11696  23407  21090
# 1642662  52001  43252   42733  21086   8706  11696  23407  21090
# 1642663  52001  43252   42733  21086   8706  11696  23407  21090
#
#          total_population      sex  age  total municipality_clean  \
# 0                    2965    Males    0     11   alegria-dulantzi
# 1                    2965    Males    1      9   alegria-dulantzi
# 2                    2965    Males    2     15   alegria-dulantzi
# 3                    2965    Males    3     12   alegria-dulantzi
# 4                    2965    Males    4      9   alegria-dulantzi
# ...                   ...      ...  ...    ...                ...
# 1642659             85985  Females   96     10            melilla
# 1642660             85985  Females   97     11            melilla
# 1642661             85985  Females   98      9            melilla
# 1642662             85985  Females   99      1            melilla
# 1642663             85985  Females  100     12            melilla
#
#            province_clean age_group
# 0        alegria-dulantzi      0-17
# 1        alegria-dulantzi      0-17
# 2        alegria-dulantzi      0-17
# 3        alegria-dulantzi      0-17
# 4        alegria-dulantzi      0-17
# ...                   ...       ...
# 1642659           melilla       55+
# 1642660           melilla       55+
# 1642661           melilla       55+
# 1642662           melilla       55+
# 1642663           melilla       55+
#
# [1642664 rows x 15 columns]

# %%
df_demographics_combined = df_demographics_combined[["cmun", "municipality_clean", "province_clean", "0-17", "18-24", "25-34", "35-54","55+", "male", "female","total_population"]]

# %%
df_demographics_combined
# Out:
#           cmun municipality_clean    province_clean   0-17  18-24  25-34  \
# 0         1001   alegria-dulantzi  alegria-dulantzi    615    250    268
# 1         1001   alegria-dulantzi  alegria-dulantzi    615    250    268
# 2         1001   alegria-dulantzi  alegria-dulantzi    615    250    268
# 3         1001   alegria-dulantzi  alegria-dulantzi    615    250    268
# 4         1001   alegria-dulantzi  alegria-dulantzi    615    250    268
# ...        ...                ...               ...    ...    ...    ...
# 1642659  52001            melilla           melilla  21086   8706  11696
# 1642660  52001            melilla           melilla  21086   8706  11696
# 1642661  52001            melilla           melilla  21086   8706  11696
# 1642662  52001            melilla           melilla  21086   8706  11696
# 1642663  52001            melilla           melilla  21086   8706  11696
#
#          35-54    55+   male  female  total_population
# 0         1005    827   1525    1440              2965
# 1         1005    827   1525    1440              2965
# 2         1005    827   1525    1440              2965
# 3         1005    827   1525    1440              2965
# 4         1005    827   1525    1440              2965
# ...        ...    ...    ...     ...               ...
# 1642659  23407  21090  43252   42733             85985
# 1642660  23407  21090  43252   42733             85985
# 1642661  23407  21090  43252   42733             85985
# 1642662  23407  21090  43252   42733             85985
# 1642663  23407  21090  43252   42733             85985
#
# [1642664 rows x 11 columns]

# %%
df_demographics_combined = df_demographics_combined.drop_duplicates()
df_demographics_combined
# Out:
#           cmun     municipality_clean         province_clean   0-17  18-24  \
# 0         1001       alegria-dulantzi       alegria-dulantzi    615    250
# 202       1002                amurrio                amurrio   1826    588
# 404       1003                aramaio                aramaio    218    113
# 606       1004             artziniega             artziniega    352    127
# 808       1006                arminon                arminon     42     20
# ...        ...                    ...                    ...    ...    ...
# 1641654  50901                   biel                   biel      6      8
# 1641856  50902               marracos               marracos      4      2
# 1642058  50903  villamayor de gallego  villamayor de gallego    405    224
# 1642260  51001                  ceuta                  ceuta  18151   8386
# 1642462  52001                melilla                melilla  21086   8706
#
#          25-34  35-54    55+   male  female  total_population
# 0          268   1005    827   1525    1440              2965
# 202        862   2961   4075   5134    5178             10312
# 404        108    349    592    709     671              1380
# 606        146    576    655    914     942              1856
# 808         18     96     70    127     119               246
# ...        ...    ...    ...    ...     ...               ...
# 1641654     16     37    103    104      66               170
# 1641856      4     33     42     43      42                85
# 1642058    320    789   1114   1444    1408              2852
# 1642260  10785  23963  21894  41957   41222             83179
# 1642462  11696  23407  21090  43252   42733             85985
#
# [8132 rows x 11 columns]

# %%
df_demographics_combined.to_csv("../../data/processed/filtered_files/filtered_demographics.csv", index=False)
