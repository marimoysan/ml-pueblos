# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

import pandas as pd
import plotly.express as px
import numpy as np

from scripts.accent_cleaner import AccentCleaner
from scripts.column_aligner import ColumnAligner
from scripts.utils import split_at_char, replace_with

# %% [markdown]
# # First Part: Data Cleanup

# %%
df_raw = pd.read_csv("../data/raw/68542.csv", sep=";", decimal=",")

# %%
df_raw.head()
# Out:
#    National Total Provinces Municipalities    Sex          Age  Periodo  \
# 0  National Total       NaN            NaN  Males     All ages     2024
# 1  National Total       NaN            NaN  Males     All ages     2023
# 2  National Total       NaN            NaN  Males     All ages     2022
# 3  National Total       NaN            NaN  Males     All ages     2021
# 4  National Total       NaN            NaN  Males  0 years old     2024
#
#         Total
# 0  23.826.871
# 1  23.565.593
# 2  23.288.747
# 3  23.248.611
# 4     164.763

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10018440 entries, 0 to 10018439
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   National Total  object
#  1   Provinces       object
#  2   Municipalities  object
#  3   Sex             object
#  4   Age             object
#  5   Periodo         int64
#  6   Total           object
# dtypes: int64(1), object(6)
# memory usage: 535.0+ MB

# %%
df_raw.sample(15)
# Out:
#          National Total                  Provinces  \
# 4505925  National Total                    24 León
# 6541284  National Total              36 Pontevedra
# 2713877  National Total               15 Coruña, A
# 8568230  National Total                  45 Toledo
# 7429195  National Total                 40 Segovia
# 7089957  National Total  38 Santa Cruz de Tenerife
# 7450742  National Total                 40 Segovia
# 6100458  National Total                 32 Ourense
# 9057200  National Total              47 Valladolid
# 3378730  National Total                 18 Granada
# 5131069  National Total               26 Rioja, La
# 1560732  National Total                  09 Burgos
# 4503250  National Total                    24 León
# 8442542  National Total                  45 Toledo
# 5104177  National Total               26 Rioja, La
#
#                           Municipalities      Sex           Age  Periodo Total
# 4505925         24054 Cimanes de la Vega    Males  94 years old     2023     0
# 6541284                      36026 Marín    Males  56 years old     2024   208
# 2713877     15078 Santiago de Compostela    Males  66 years old     2023   549
# 8568230                   45175 Turleque    Males  56 years old     2022     5
# 7429195      40191 Santo Tomé del Puerto  Females  81 years old     2021     1
# 7089957                   38047 Tijarafe  Females  34 years old     2023     9
# 7450742                40211 Valdeprados    Males  62 years old     2022     1
# 6100458         32063 Pobra de Trives, A    Males   9 years old     2022     8
# 9057200  47102 Nueva Villa de las Torres    Total    1 year old     2024     0
# 3378730                    18076 Fonelas  Females  19 years old     2022     2
# 5131069                   26121 Rabanera    Males  14 years old     2023     0
# 1560732           09117 Cueva de Roa, La    Males  32 years old     2024     1
# 4503250                   24052 Cebanico    Males  37 years old     2022     3
# 8442542             45072 Herencias, Las  Females  50 years old     2022     6
# 5104177                    26098 Munilla    Males  23 years old     2023     1

# %%
df_raw.drop(columns=['National Total'], inplace=True)

# %%
df_raw.isnull().sum()
# Out:
# Provinces          1224
# Municipalities    64872
# Sex                   0
# Age                   0
# Periodo               0
# Total               918
# dtype: int64

# %%
df_municipalities_null = df_raw[df_raw['Municipalities'].isnull()]
df_municipalities_null[df_municipalities_null["Provinces"] == "08 Barcelona"]
# Out:
#             Provinces Municipalities    Sex                Age  Periodo  \
# 1064880  08 Barcelona            NaN  Males           All ages     2024
# 1064881  08 Barcelona            NaN  Males           All ages     2023
# 1064882  08 Barcelona            NaN  Males           All ages     2022
# 1064883  08 Barcelona            NaN  Males           All ages     2021
# 1064884  08 Barcelona            NaN  Males        0 years old     2024
# ...               ...            ...    ...                ...      ...
# 1066099  08 Barcelona            NaN  Total       99 years old     2021
# 1066100  08 Barcelona            NaN  Total  100 years or more     2024
# 1066101  08 Barcelona            NaN  Total  100 years or more     2023
# 1066102  08 Barcelona            NaN  Total  100 years or more     2022
# 1066103  08 Barcelona            NaN  Total  100 years or more     2021
#
#              Total
# 1064880  2.870.721
# 1064881  2.830.260
# 1064882  2.783.698
# 1064883  2.785.890
# 1064884     20.185
# ...            ...
# 1066099      1.096
# 1066100      1.982
# 1066101      1.807
# 1066102      1.707
# 1066103      1.546
#
# [1224 rows x 6 columns]

# %% [markdown]
# ### We have information about provinces without the municipalities, we should drop them

# %%
df_raw[df_raw['Provinces'] == "25 Lleida"].sample(5)
# Out:
#          Provinces              Municipalities      Sex           Age  \
# 4969498  25 Lleida  25254 Vilanova de la Barca    Males  13 years old
# 4925898  25 Lleida                 25210 Soses  Females  27 years old
# 4784474  25 Lleida                  25071 Cava    Total  65 years old
# 4971487  25 Lleida               25255 Vinaixa    Total   0 years old
# 4847437  25 Lleida            25134 Menàrguens    Males  98 years old
#
#          Periodo Total
# 4969498     2022     4
# 4925898     2022     3
# 4784474     2022     3
# 4971487     2021     3
# 4847437     2023     0

# %%
prov_null = df_raw[["Provinces", "Municipalities"]]

prov_null[(prov_null["Provinces"].isnull()) & (prov_null["Municipalities"].isnull())]
# Out:
#      Provinces Municipalities
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# ...        ...            ...
# 1219       NaN            NaN
# 1220       NaN            NaN
# 1221       NaN            NaN
# 1222       NaN            NaN
# 1223       NaN            NaN
#
# [1224 rows x 2 columns]

# %%
prov_null[(prov_null["Provinces"].isnull())]
# Out:
#      Provinces Municipalities
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# ...        ...            ...
# 1219       NaN            NaN
# 1220       NaN            NaN
# 1221       NaN            NaN
# 1222       NaN            NaN
# 1223       NaN            NaN
#
# [1224 rows x 2 columns]

# %%
df_raw[df_raw['Total'].isnull()].sample(30)
# Out:
#           Provinces Municipalities      Sex           Age  Periodo Total
# 9348473  48 Bizkaia       48916 NA  Females  93 years old     2023   NaN
# 9347914  48 Bizkaia       48916 NA    Males  55 years old     2022   NaN
# 9348282  48 Bizkaia       48916 NA  Females  45 years old     2022   NaN
# 9348351  48 Bizkaia       48916 NA  Females  62 years old     2021   NaN
# 9347758  48 Bizkaia       48916 NA    Males  16 years old     2022   NaN
# 9348706  48 Bizkaia       48916 NA    Total  49 years old     2022   NaN
# 9348743  48 Bizkaia       48916 NA    Total  58 years old     2021   NaN
# 9348431  48 Bizkaia       48916 NA  Females  82 years old     2021   NaN
# 9347722  48 Bizkaia       48916 NA    Males   7 years old     2022   NaN
# 9348862  48 Bizkaia       48916 NA    Total  88 years old     2022   NaN
# 9348270  48 Bizkaia       48916 NA  Females  42 years old     2022   NaN
# 9348050  48 Bizkaia       48916 NA    Males  89 years old     2022   NaN
# 9347881  48 Bizkaia       48916 NA    Males  47 years old     2023   NaN
# 9348470  48 Bizkaia       48916 NA  Females  92 years old     2022   NaN
# 9348474  48 Bizkaia       48916 NA  Females  93 years old     2022   NaN
# 9348079  48 Bizkaia       48916 NA    Males  96 years old     2021   NaN
# 9348222  48 Bizkaia       48916 NA  Females  30 years old     2022   NaN
# 9347745  48 Bizkaia       48916 NA    Males  13 years old     2023   NaN
# 9347861  48 Bizkaia       48916 NA    Males  42 years old     2023   NaN
# 9348027  48 Bizkaia       48916 NA    Males  83 years old     2021   NaN
# 9348622  48 Bizkaia       48916 NA    Total  28 years old     2022   NaN
# 9347937  48 Bizkaia       48916 NA    Males  61 years old     2023   NaN
# 9348189  48 Bizkaia       48916 NA  Females  22 years old     2023   NaN
# 9347693  48 Bizkaia       48916 NA    Males   0 years old     2023   NaN
# 9348183  48 Bizkaia       48916 NA  Females  20 years old     2021   NaN
# 9348102  48 Bizkaia       48916 NA  Females   0 years old     2022   NaN
# 9347710  48 Bizkaia       48916 NA    Males   4 years old     2022   NaN
# 9348619  48 Bizkaia       48916 NA    Total  27 years old     2021   NaN
# 9348514  48 Bizkaia       48916 NA    Total    1 year old     2022   NaN
# 9347751  48 Bizkaia       48916 NA    Males  14 years old     2021   NaN

# %%
df_raw.sample(20)
# Out:
#              Provinces                  Municipalities      Sex           Age  \
# 812280      06 Badajoz  06027 Calzadilla de los Barros  Females  89 years old
# 2600943     14 Córdoba             14061 Santa Eufemia    Total  86 years old
# 4496983        24 León              24046 Castrocalbón    Males   0 years old
# 6852284   37 Salamanca                  37233 Pastores    Males  82 years old
# 9442140      49 Zamora                   49085 Galende    Males  50 years old
# 8394508      45 Toledo               45032 Camarenilla    Males  78 years old
# 6761486   37 Salamanca                  37156 Guijuelo    Males  26 years old
# 6691261   37 Salamanca   37092 Castellanos de Moriscos    Total  14 years old
# 1184224   08 Barcelona                    08097 Gualba  Females  51 years old
# 889284      06 Badajoz      06090 Nava de Santiago, La  Females  62 years old
# 5112468   26 Rioja, La                   26104 Navajún    Total  56 years old
# 8966154  47 Valladolid       47027 Cabezón de Pisuerga    Males  87 years old
# 898824      06 Badajoz                   06098 Palomas  Females      All ages
# 8284615      44 Teruel                44203 Salcedillo  Females  42 years old
# 5644329      30 Murcia                   30009 Archena  Females  13 years old
# 6860376   37 Salamanca  37239 Pedroso de la Armuña, El    Total  65 years old
# 6412804    34 Palencia             34189 Valdeolmillos    Males  66 years old
# 9923119    50 Zaragoza            50228 Rueda de Jalón    Males  36 years old
# 6166612    33 Asturias                     33024 Gijón    Males  24 years old
# 6877222   37 Salamanca        37253 Pino de Tormes, El  Females  94 years old
#
#          Periodo  Total
# 812280      2024      2
# 2600943     2021      8
# 4496983     2021      1
# 6852284     2024      1
# 9442140     2024      7
# 8394508     2024      6
# 6761486     2022     37
# 6691261     2023     34
# 1184224     2024     14
# 889284      2024     14
# 5112468     2024      0
# 8966154     2022      5
# 898824      2024    331
# 8284615     2021      0
# 5644329     2023    100
# 6860376     2024      3
# 6412804     2024      0
# 9923119     2021      3
# 6166612     2024  1.193
# 6877222     2022      0

# %%
df_raw = df_raw.dropna(subset=["Provinces", "Municipalities", "Total"], how="any")

# %%
df_2024 = df_raw[df_raw['Periodo'] == 2024].copy()

# %%
df_2024.reset_index(drop=True, inplace=True)

# %%
idx = pd.Index(["Provinces", "Municipalities", "Sex", "Age", "Periodo", "Total"])
eng = pd.Index(["province", "municipality", "sex", "age", "year", "total"])

df_2024.rename(columns=dict(zip(idx, eng)), inplace=True)

# %% [markdown]
# ### Get the correct types

# %%
df_2024["total"] = pd.to_numeric(df_2024["total"].str.replace(".", "", regex=False)).astype("int32")

# %%
df_2024 = df_2024[df_2024["age"] != "All ages"]

# %%
(df_2024["age"].str.contains(r"^\d"))
# Out:
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
#            ...
# 2488387    True
# 2488388    True
# 2488389    True
# 2488390    True
# 2488391    True
# Name: age, Length: 2463996, dtype: bool

# %%
df_2024.head()
# Out:
#          province            municipality    sex          age  year  total
# 1  01 Araba/Álava  01001 Alegría-Dulantzi  Males  0 years old  2024     11
# 2  01 Araba/Álava  01001 Alegría-Dulantzi  Males   1 year old  2024      9
# 3  01 Araba/Álava  01001 Alegría-Dulantzi  Males  2 years old  2024     15
# 4  01 Araba/Álava  01001 Alegría-Dulantzi  Males  3 years old  2024     12
# 5  01 Araba/Álava  01001 Alegría-Dulantzi  Males  4 years old  2024      9

# %%
from scripts.utils import split_column_at
df_2024["age"] = split_column_at(df_2024, "age", " ", index=0)
df_2024["province"] = split_column_at(df_2024, "province", " ", index=1)
df_2024["cprov"] = split_column_at(df_2024, "province", " ", index=0)
df_2024["cmun"] = split_column_at(df_2024, "municipality", " ", index=0)
df_2024["municipality"] = split_column_at(df_2024, "municipality", " ", index=1)

# %%
df_2024
# Out:
#             province      municipality    sex  age  year  total        cprov  \
# 1        Araba/Álava  Alegría-Dulantzi  Males    0  2024     11  Araba/Álava
# 2        Araba/Álava  Alegría-Dulantzi  Males    1  2024      9  Araba/Álava
# 3        Araba/Álava  Alegría-Dulantzi  Males    2  2024     15  Araba/Álava
# 4        Araba/Álava  Alegría-Dulantzi  Males    3  2024     12  Araba/Álava
# 5        Araba/Álava  Alegría-Dulantzi  Males    4  2024      9  Araba/Álava
# ...              ...               ...    ...  ...   ...    ...          ...
# 2488387      Melilla           Melilla  Total   96  2024     19      Melilla
# 2488388      Melilla           Melilla  Total   97  2024     13      Melilla
# 2488389      Melilla           Melilla  Total   98  2024     11      Melilla
# 2488390      Melilla           Melilla  Total   99  2024      3      Melilla
# 2488391      Melilla           Melilla  Total  100  2024     12      Melilla
#
#           cmun
# 1        01001
# 2        01001
# 3        01001
# 4        01001
# 5        01001
# ...        ...
# 2488387  52001
# 2488388  52001
# 2488389  52001
# 2488390  52001
# 2488391  52001
#
# [2463996 rows x 8 columns]

# %%
df_2024.drop("cprov", axis = 1, inplace=True)

# %%
df_2024["age"] = pd.to_numeric(df_2024["age"].str.replace(".", "", regex=False)).astype("int32")

# %%
cleaner = AccentCleaner([df_2024], ['municipality', 'province'])
cleaner.cleanAccents()

# %%
df_2024.sample(10)
# Out:
#                    province         municipality      sex  age  year  total  \
# 587094   Castellón/Castelló             Torralba  Females   83  2024      0
# 1200730              Lleida             Lladorre    Total   87  2024      1
# 326960            Barcelona                 Sant  Females   49  2024     63
# 1162577                León          Villamartín    Males   82  2024      0
# 1197336              Lleida             Guissona    Total   59  2024     73
# 774054               Girona                  Ger  Females   77  2024      3
# 578902   Castellón/Castelló  Peníscola/Peñíscola    Total   51  2024    127
# 2311481             Bizkaia          Portugalete    Total   58  2024    738
# 2235704          Valladolid             Corrales    Males   67  2024      2
# 941772          Guadalajara             Taragudo    Total    5  2024      0
#
#           cmun   municipality_clean      province_clean
# 587094   12116             torralba  castellon/castello
# 1200730  25123             lladorre              lleida
# 326960   08209                 sant           barcelona
# 1162577  24213          villamartin                leon
# 1197336  25110             guissona              lleida
# 774054   17078                  ger              girona
# 578902   12089  peniscola/peniscola  castellon/castello
# 2311481  48078          portugalete             bizkaia
# 2235704  47056             corrales          valladolid
# 941772   19263             taragudo         guadalajara

# %%
df_2024["province"] = split_column_at(df_2024, "province", " ", index=0)

# %%
df_2024["cmun"] = pd.to_numeric(df_2024["cmun"].str.replace(".", "", regex=False)).astype("int32")

# %%
df_2024.sample(10)
# Out:
#             province   municipality      sex  age  year  total   cmun  \
# 888025   Guadalajara       Campillo    Males   12  2024      0  19060
# 393155        Burgos  Fuentemolinos    Total   46  2024      0   9139
# 1652707    Salamanca     Buenavista    Males    0  2024      1  37060
# 138454         Ávila         Gemuño  Females   39  2024      0   5083
# 1670002    Salamanca       Espadaña  Females   57  2024      0  37126
# 40467       Albacete      Villatoya    Males   74  2024      0   2082
# 1988342    Tarragona          Santa    Total   55  2024     59  43138
# 1442537      Navarra      Esteribar    Males   52  2024     34  31098
# 1151380         León          Torre    Total    3  2024      6  24170
# 260488      Balears,       Santanyí    Males   81  2024     27   7057
#
#         municipality_clean province_clean
# 888025            campillo    guadalajara
# 393155       fuentemolinos         burgos
# 1652707         buenavista      salamanca
# 138454              gemuno          avila
# 1670002           espadana      salamanca
# 40467            villatoya       albacete
# 1988342              santa      tarragona
# 1442537          esteribar        navarra
# 1151380              torre           leon
# 260488            santanyi       balears,

# %%
df_2024.to_csv("../data/large_files/filtered_age.csv", index=False)

# %% [markdown]
# # Second Part: Binning and Pivoting

# %%
df_ages_bined = pd.read_csv("../data/large_files/filtered_age.csv")

df_ages_bined.shape
df_ages_bined.head()
# Out:
#       province      municipality    sex  age  year  total  cmun  \
# 0  Araba/Álava  Alegría-Dulantzi  Males    0  2024     11  1001
# 1  Araba/Álava  Alegría-Dulantzi  Males    1  2024      9  1001
# 2  Araba/Álava  Alegría-Dulantzi  Males    2  2024     15  1001
# 3  Araba/Álava  Alegría-Dulantzi  Males    3  2024     12  1001
# 4  Araba/Álava  Alegría-Dulantzi  Males    4  2024      9  1001
#
#   municipality_clean province_clean
# 0   alegria-dulantzi    araba/alava
# 1   alegria-dulantzi    araba/alava
# 2   alegria-dulantzi    araba/alava
# 3   alegria-dulantzi    araba/alava
# 4   alegria-dulantzi    araba/alava

# %%
df_demographics = df_ages_bined.query("sex != 'Total'")

# %%
df_demographics.isna().sum()
# Out:
# province                0
# municipality          202
# sex                     0
# age                     0
# year                    0
# total                   0
# cmun                    0
# municipality_clean      0
# province_clean          0
# dtype: int64

# %%
def assign_age_group(age):
    if age <= 17:
        return '0-17'
    elif age <= 24:
        return '18-24'
    elif age <= 34:
        return '25-34'
    elif age <= 54:
        return '35-54'
    else:
        return '55+'

df_demographics['age_group'] = df_demographics['age'].apply(assign_age_group)
# Out:
# C:\Users\Marina\AppData\Local\Temp\ipykernel_20864\3734956762.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_demographics['age_group'] = df_demographics['age'].apply(assign_age_group)

# %%
df_demographics["age_group"].unique()
# Out:
# array(['0-17', '18-24', '25-34', '35-54', '55+'], dtype=object)

# %%
# 2. Pivot the table to have one column per age group
#    We group by 'cmun' (or whichever municipality identifier you prefer)
pivot_df = df_demographics.pivot_table(
    index='cmun',
    columns='age_group',
    values='total',
    aggfunc='sum',
    fill_value=0  # fill missing combinations with 0
).reset_index()

# %%
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
pivot_df = pivot_df[['cmun'] + [grp for grp in age_group_order if grp in pivot_df.columns]]
pivot_df["total_population"] = pivot_df["0-17"] + pivot_df["18-24"] + pivot_df["25-34"] + pivot_df["35-54"] + pivot_df["55+"]

pivot_df
# Out:
# age_group   cmun   0-17  18-24  25-34  35-54    55+  total_population
# 0           1001    615    250    268   1005    827              2965
# 1           1002   1826    588    862   2961   4075             10312
# 2           1003    218    113    108    349    592              1380
# 3           1004    352    127    146    576    655              1856
# 4           1006     42     20     18     96     70               246
# ...          ...    ...    ...    ...    ...    ...               ...
# 8127       50901      6      8     16     37    103               170
# 8128       50902      4      2      4     33     42                85
# 8129       50903    405    224    320    789   1114              2852
# 8130       51001  18151   8386  10785  23963  21894             83179
# 8131       52001  21086   8706  11696  23407  21090             85985
#
# [8132 rows x 7 columns]

# %%
pivot_df_sex = df_demographics.pivot_table(
    index='cmun',
    columns='sex',
    values='total',
    aggfunc='sum',
    fill_value=0  # fill missing combinations with 0
).reset_index()

# %%
df_demographics["sex"].unique()
# Out:
# array(['Males', 'Females'], dtype=object)

# %%
sex_group_order = ['Males', 'Females']

pivot_df_sex = pivot_df_sex[['cmun'] + [grp for grp in sex_group_order if grp in pivot_df_sex.columns]]
pivot_df_sex.rename(columns={"Males": "male", "Females": "female"}, inplace=True)

pivot_df_sex["total_sex"] = pivot_df_sex["male"] + pivot_df_sex["female"]
pivot_df_sex
# Out:
# sex    cmun   male  female  total_sex
# 0      1001   1525    1440       2965
# 1      1002   5134    5178      10312
# 2      1003    709     671       1380
# 3      1004    914     942       1856
# 4      1006    127     119        246
# ...     ...    ...     ...        ...
# 8127  50901    104      66        170
# 8128  50902     43      42         85
# 8129  50903   1444    1408       2852
# 8130  51001  41957   41222      83179
# 8131  52001  43252   42733      85985
#
# [8132 rows x 4 columns]

# %%
df_demographics_combined = pivot_df.merge(df_demographics, on='cmun', how='left')
df_demographics_combined = pivot_df_sex.merge(df_demographics_combined, on='cmun', how='left')

df_demographics_combined
# Out:
#           cmun   male  female  total_sex   0-17  18-24  25-34  35-54    55+  \
# 0         1001   1525    1440       2965    615    250    268   1005    827
# 1         1001   1525    1440       2965    615    250    268   1005    827
# 2         1001   1525    1440       2965    615    250    268   1005    827
# 3         1001   1525    1440       2965    615    250    268   1005    827
# 4         1001   1525    1440       2965    615    250    268   1005    827
# ...        ...    ...     ...        ...    ...    ...    ...    ...    ...
# 1642659  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642660  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642661  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642662  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642663  52001  43252   42733      85985  21086   8706  11696  23407  21090
#
#          total_population     province      municipality      sex  age  year  \
# 0                    2965  Araba/Álava  Alegría-Dulantzi    Males    0  2024
# 1                    2965  Araba/Álava  Alegría-Dulantzi    Males    1  2024
# 2                    2965  Araba/Álava  Alegría-Dulantzi    Males    2  2024
# 3                    2965  Araba/Álava  Alegría-Dulantzi    Males    3  2024
# 4                    2965  Araba/Álava  Alegría-Dulantzi    Males    4  2024
# ...                   ...          ...               ...      ...  ...   ...
# 1642659             85985      Melilla           Melilla  Females   96  2024
# 1642660             85985      Melilla           Melilla  Females   97  2024
# 1642661             85985      Melilla           Melilla  Females   98  2024
# 1642662             85985      Melilla           Melilla  Females   99  2024
# 1642663             85985      Melilla           Melilla  Females  100  2024
#
#          total municipality_clean province_clean age_group
# 0           11   alegria-dulantzi    araba/alava      0-17
# 1            9   alegria-dulantzi    araba/alava      0-17
# 2           15   alegria-dulantzi    araba/alava      0-17
# 3           12   alegria-dulantzi    araba/alava      0-17
# 4            9   alegria-dulantzi    araba/alava      0-17
# ...        ...                ...            ...       ...
# 1642659     10            melilla        melilla       55+
# 1642660     11            melilla        melilla       55+
# 1642661      9            melilla        melilla       55+
# 1642662      1            melilla        melilla       55+
# 1642663     12            melilla        melilla       55+
#
# [1642664 rows x 19 columns]

# %%
df_demographics_combined = df_demographics_combined.drop(["year", "municipality", "province", "total_sex"], axis = 1)

# %%
df_demographics_combined
# Out:
#           cmun   male  female   0-17  18-24  25-34  35-54    55+  \
# 0         1001   1525    1440    615    250    268   1005    827
# 1         1001   1525    1440    615    250    268   1005    827
# 2         1001   1525    1440    615    250    268   1005    827
# 3         1001   1525    1440    615    250    268   1005    827
# 4         1001   1525    1440    615    250    268   1005    827
# ...        ...    ...     ...    ...    ...    ...    ...    ...
# 1642659  52001  43252   42733  21086   8706  11696  23407  21090
# 1642660  52001  43252   42733  21086   8706  11696  23407  21090
# 1642661  52001  43252   42733  21086   8706  11696  23407  21090
# 1642662  52001  43252   42733  21086   8706  11696  23407  21090
# 1642663  52001  43252   42733  21086   8706  11696  23407  21090
#
#          total_population      sex  age  total municipality_clean  \
# 0                    2965    Males    0     11   alegria-dulantzi
# 1                    2965    Males    1      9   alegria-dulantzi
# 2                    2965    Males    2     15   alegria-dulantzi
# 3                    2965    Males    3     12   alegria-dulantzi
# 4                    2965    Males    4      9   alegria-dulantzi
# ...                   ...      ...  ...    ...                ...
# 1642659             85985  Females   96     10            melilla
# 1642660             85985  Females   97     11            melilla
# 1642661             85985  Females   98      9            melilla
# 1642662             85985  Females   99      1            melilla
# 1642663             85985  Females  100     12            melilla
#
#         province_clean age_group
# 0          araba/alava      0-17
# 1          araba/alava      0-17
# 2          araba/alava      0-17
# 3          araba/alava      0-17
# 4          araba/alava      0-17
# ...                ...       ...
# 1642659        melilla       55+
# 1642660        melilla       55+
# 1642661        melilla       55+
# 1642662        melilla       55+
# 1642663        melilla       55+
#
# [1642664 rows x 15 columns]

# %%
df_demographics_combined = df_demographics_combined[["cmun", "municipality_clean", "province_clean", "0-17", "18-24", "25-34", "35-54","55+", "male", "female","total_population"]]

# %%
df_demographics_combined
# Out:
#           cmun municipality_clean province_clean   0-17  18-24  25-34  35-54  \
# 0         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# 1         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# 2         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# 3         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# 4         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# ...        ...                ...            ...    ...    ...    ...    ...
# 1642659  52001            melilla        melilla  21086   8706  11696  23407
# 1642660  52001            melilla        melilla  21086   8706  11696  23407
# 1642661  52001            melilla        melilla  21086   8706  11696  23407
# 1642662  52001            melilla        melilla  21086   8706  11696  23407
# 1642663  52001            melilla        melilla  21086   8706  11696  23407
#
#            55+   male  female  total_population
# 0          827   1525    1440              2965
# 1          827   1525    1440              2965
# 2          827   1525    1440              2965
# 3          827   1525    1440              2965
# 4          827   1525    1440              2965
# ...        ...    ...     ...               ...
# 1642659  21090  43252   42733             85985
# 1642660  21090  43252   42733             85985
# 1642661  21090  43252   42733             85985
# 1642662  21090  43252   42733             85985
# 1642663  21090  43252   42733             85985
#
# [1642664 rows x 11 columns]

# %%
df_demographics_combined = df_demographics_combined.drop_duplicates()
df_demographics_combined
# Out:
#           cmun municipality_clean province_clean   0-17  18-24  25-34  35-54  \
# 0         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# 202       1002            amurrio    araba/alava   1826    588    862   2961
# 404       1003            aramaio    araba/alava    218    113    108    349
# 606       1004         artziniega    araba/alava    352    127    146    576
# 808       1006            arminon    araba/alava     42     20     18     96
# ...        ...                ...            ...    ...    ...    ...    ...
# 1641654  50901               biel       zaragoza      6      8     16     37
# 1641856  50902           marracos       zaragoza      4      2      4     33
# 1642058  50903         villamayor       zaragoza    405    224    320    789
# 1642260  51001              ceuta          ceuta  18151   8386  10785  23963
# 1642462  52001            melilla        melilla  21086   8706  11696  23407
#
#            55+   male  female  total_population
# 0          827   1525    1440              2965
# 202       4075   5134    5178             10312
# 404        592    709     671              1380
# 606        655    914     942              1856
# 808         70    127     119               246
# ...        ...    ...     ...               ...
# 1641654    103    104      66               170
# 1641856     42     43      42                85
# 1642058   1114   1444    1408              2852
# 1642260  21894  41957   41222             83179
# 1642462  21090  43252   42733             85985
#
# [8132 rows x 11 columns]

# %%
df_demographics_combined.to_csv("../data/processed/filtered_files/filtered_demographics.csv", index=False)
