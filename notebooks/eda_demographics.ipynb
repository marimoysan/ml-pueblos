# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

import pandas as pd
import plotly.express as px
import numpy as np

from scripts.accent_cleaner import AccentCleaner
from scripts.column_aligner import ColumnAligner
from scripts.utils import split_at_char, replace_with

# %%
df_raw = pd.read_csv("../data/raw/68542.csv", sep=";", decimal=",")

# %%
df_raw.head()
# Out:
#    National Total Provinces Municipalities    Sex          Age  Periodo
# 0  National Total       NaN            NaN  Males     All ages     2024  \
# 1  National Total       NaN            NaN  Males     All ages     2023
# 2  National Total       NaN            NaN  Males     All ages     2022
# 3  National Total       NaN            NaN  Males     All ages     2021
# 4  National Total       NaN            NaN  Males  0 years old     2024
#
#         Total
# 0  23.826.871
# 1  23.565.593
# 2  23.288.747
# 3  23.248.611
# 4     164.763

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10018440 entries, 0 to 10018439
# Data columns (total 7 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   National Total  object
#  1   Provinces       object
#  2   Municipalities  object
#  3   Sex             object
#  4   Age             object
#  5   Periodo         int64
#  6   Total           object
# dtypes: int64(1), object(6)
# memory usage: 535.0+ MB

# %%
df_raw.sample(15)
# Out:
#          National Total              Provinces
# 9483284  National Total              49 Zamora  \
# 9241808  National Total             48 Bizkaia
# 7638194  National Total               42 Soria
# 1306208  National Total           08 Barcelona
# 7777727  National Total               42 Soria
# 215452   National Total    03 Alicante/Alacant
# 7025675  National Total           37 Salamanca
# 1019650  National Total      07 Balears, Illes
# 2323783  National Total  12 Castellón/Castelló
# 6287001  National Total            34 Palencia
# 1932871  National Total             10 Cáceres
# 4186852  National Total              22 Huesca
# 5294359  National Total              28 Madrid
# 9114057  National Total          47 Valladolid
# 8033288  National Total           43 Tarragona
#
#                             Municipalities      Sex           Age  Periodo
# 9483284  49120 Molezuelas de la Carballeda    Total  34 years old     2024  \
# 9241808                         48026 Dima  Females  49 years old     2024
# 7638194             42022 Almenar de Soria  Females   5 years old     2022
# 1306208       08199 Sant Bartomeu del Grau    Males  49 years old     2024
# 7777727                     42161 Salduero  Females   4 years old     2021
# 215452                     03035 Benilloba    Males   6 years old     2024
# 7025675              37377 Yecla de Yeltes    Total  79 years old     2021
# 1019650                    07031 Llucmajor    Males  13 years old     2022
# 2323783                        12082 Nules  Females  54 years old     2021
# 6287001          34056 Cervera de Pisuerga  Females  31 years old     2023
# 1932871                      10025 Barrado    Males  42 years old     2021
# 4186852                        22112 Fraga  Females  90 years old     2024
# 5294359                     28007 Alcorcón  Females  36 years old     2021
# 9114057          47153 Santervás de Campos    Males  37 years old     2023
# 8033288                     43160 Vallmoll    Males  43 years old     2024
#
#          Total
# 9483284      0
# 9241808      8
# 7638194      0
# 1306208     13
# 7777727      0
# 215452       2
# 7025675      3
# 1019650    259
# 2323783     83
# 6287001      5
# 1932871      1
# 4186852     27
# 5294359  1.075
# 9114057      0
# 8033288     21

# %%
df_raw.drop(columns=['National Total'], inplace=True)

# %%
df_raw.isnull().sum()
# Out:
# Provinces          1224
# Municipalities    64872
# Sex                   0
# Age                   0
# Periodo               0
# Total               918
# dtype: int64

# %%
df_municipalities_null = df_raw[df_raw['Municipalities'].isnull()]
df_municipalities_null[df_municipalities_null["Provinces"] == "08 Barcelona"]
# Out:
#             Provinces Municipalities    Sex                Age  Periodo
# 1064880  08 Barcelona            NaN  Males           All ages     2024  \
# 1064881  08 Barcelona            NaN  Males           All ages     2023
# 1064882  08 Barcelona            NaN  Males           All ages     2022
# 1064883  08 Barcelona            NaN  Males           All ages     2021
# 1064884  08 Barcelona            NaN  Males        0 years old     2024
# ...               ...            ...    ...                ...      ...
# 1066099  08 Barcelona            NaN  Total       99 years old     2021
# 1066100  08 Barcelona            NaN  Total  100 years or more     2024
# 1066101  08 Barcelona            NaN  Total  100 years or more     2023
# 1066102  08 Barcelona            NaN  Total  100 years or more     2022
# 1066103  08 Barcelona            NaN  Total  100 years or more     2021
#
#              Total
# 1064880  2.870.721
# 1064881  2.830.260
# 1064882  2.783.698
# 1064883  2.785.890
# 1064884     20.185
# ...            ...
# 1066099      1.096
# 1066100      1.982
# 1066101      1.807
# 1066102      1.707
# 1066103      1.546
#
# [1224 rows x 6 columns]

# %% [markdown]
# ### We have information about provinces without the municipalities, we should drop them

# %%
df_raw[df_raw['Provinces'] == "25 Lleida"].sample(5)
# Out:
#          Provinces                Municipalities      Sex           Age
# 4869691  25 Lleida  25154 Omells de na Gaia, Els  Females  51 years old  \
# 4798328  25 Lleida          25086 Esterri d'Àneu    Males  61 years old
# 4826240  25 Lleida     25115 Isona i Conca Dellà    Males    1 year old
# 4953894  25 Lleida    25239 Valls de Valira, Les    Males  90 years old
# 4833806  25 Lleida                25123 Lladorre    Males  56 years old
#
#          Periodo Total
# 4869691     2021     3
# 4798328     2024     6
# 4826240     2024     4
# 4953894     2022     0
# 4833806     2022     1

# %%
prov_null = df_raw[["Provinces", "Municipalities"]]

prov_null[(prov_null["Provinces"].isnull()) & (prov_null["Municipalities"].isnull())]
# Out:
#      Provinces Municipalities
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# ...        ...            ...
# 1219       NaN            NaN
# 1220       NaN            NaN
# 1221       NaN            NaN
# 1222       NaN            NaN
# 1223       NaN            NaN
#
# [1224 rows x 2 columns]

# %%
prov_null[(prov_null["Provinces"].isnull())]
# Out:
#      Provinces Municipalities
# 0          NaN            NaN
# 1          NaN            NaN
# 2          NaN            NaN
# 3          NaN            NaN
# 4          NaN            NaN
# ...        ...            ...
# 1219       NaN            NaN
# 1220       NaN            NaN
# 1221       NaN            NaN
# 1222       NaN            NaN
# 1223       NaN            NaN
#
# [1224 rows x 2 columns]

# %%
df_raw[df_raw['Total'].isnull()].sample(30)
# Out:
#           Provinces Municipalities      Sex           Age  Periodo Total
# 9348363  48 Bizkaia       48916 NA  Females  65 years old     2021   NaN
# 9348491  48 Bizkaia       48916 NA  Females  97 years old     2021   NaN
# 9348339  48 Bizkaia       48916 NA  Females  59 years old     2021   NaN
# 9348895  48 Bizkaia       48916 NA    Total  96 years old     2021   NaN
# 9348353  48 Bizkaia       48916 NA  Females  63 years old     2023   NaN
# 9348497  48 Bizkaia       48916 NA  Females  99 years old     2023   NaN
# 9348035  48 Bizkaia       48916 NA    Males  85 years old     2021   NaN
# 9347777  48 Bizkaia       48916 NA    Males  21 years old     2023   NaN
# 9348830  48 Bizkaia       48916 NA    Total  80 years old     2022   NaN
# 9347994  48 Bizkaia       48916 NA    Males  75 years old     2022   NaN
# 9348709  48 Bizkaia       48916 NA    Total  50 years old     2023   NaN
# 9348569  48 Bizkaia       48916 NA    Total  15 years old     2023   NaN
# 9347715  48 Bizkaia       48916 NA    Males   5 years old     2021   NaN
# 9348253  48 Bizkaia       48916 NA  Females  38 years old     2023   NaN
# 9348065  48 Bizkaia       48916 NA    Males  93 years old     2023   NaN
# 9348705  48 Bizkaia       48916 NA    Total  49 years old     2023   NaN
# 9348341  48 Bizkaia       48916 NA  Females  60 years old     2023   NaN
# 9348645  48 Bizkaia       48916 NA    Total  34 years old     2023   NaN
# 9348290  48 Bizkaia       48916 NA  Females  47 years old     2022   NaN
# 9348071  48 Bizkaia       48916 NA    Males  94 years old     2021   NaN
# 9348310  48 Bizkaia       48916 NA  Females  52 years old     2022   NaN
# 9347862  48 Bizkaia       48916 NA    Males  42 years old     2022   NaN
# 9348103  48 Bizkaia       48916 NA  Females   0 years old     2021   NaN
# 9348114  48 Bizkaia       48916 NA  Females   3 years old     2022   NaN
# 9348674  48 Bizkaia       48916 NA    Total  41 years old     2022   NaN
# 9348861  48 Bizkaia       48916 NA    Total  88 years old     2023   NaN
# 9348754  48 Bizkaia       48916 NA    Total  61 years old     2022   NaN
# 9348585  48 Bizkaia       48916 NA    Total  19 years old     2023   NaN
# 9348286  48 Bizkaia       48916 NA  Females  46 years old     2022   NaN
# 9348671  48 Bizkaia       48916 NA    Total  40 years old     2021   NaN

# %%
df_raw.sample(20)
# Out:
#                      Provinces                 Municipalities      Sex
# 7929752           43 Tarragona      43074 Llorenç del Penedès  Females  \
# 5478027              28 Madrid    28164 Valdetorres de Jarama  Females
# 5236424                27 Lugo                     27028 Lugo    Males
# 1086440           08 Barcelona                  08017 Balenyà  Females
# 2044382             10 Cáceres                10117 Marchagaz    Males
# 2836799              16 Cuenca                16093 Garaballa  Females
# 7256283             40 Segovia                  40028 Bercial  Females
# 5563498              29 Málaga             29047 Cuevas Bajas  Females
# 2362407  12 Castellón/Castelló                 12115 Toro, El    Males
# 2874347              16 Cuenca        16128 Monreal del Llano    Males
# 3379658             18 Granada                   18077 Fornes    Males
# 908308              06 Badajoz         06106 Puebla del Prior    Males
# 1014644      07 Balears, Illes                  07026 Eivissa    Total
# 6391963            34 Palencia  34167 Santa Cecilia del Alcor    Males
# 2428880         13 Ciudad Real              13024 Brazatortas  Females
# 6932082           37 Salamanca                   37299 Santiz  Females
# 6674712           37 Salamanca               37078 Candelario    Males
# 4591193                24 León                   24129 Reyero    Total
# 7129171           39 Cantabria                 39024 Comillas  Females
# 68149              02 Albacete                   02002 Alatoz    Total
#
#                   Age  Periodo Total
# 7929752  67 years old     2024    14
# 5478027  53 years old     2021    43
# 5236424  37 years old     2024   526
# 1086440  85 years old     2024     6
# 2044382  74 years old     2022     2
# 2836799  94 years old     2021     0
# 7256283      All ages     2021    48
# 5563498    1 year old     2022     8
# 2362407  20 years old     2021     0
# 2874347  97 years old     2021     0
# 3379658  47 years old     2022     4
# 908308   24 years old     2024     3
# 1014644  88 years old     2024   120
# 6391963  57 years old     2021     0
# 2428880  13 years old     2024     0
# 6932082  39 years old     2022     0
# 6674712  59 years old     2024     8
# 4591193  93 years old     2023     0
# 7129171  45 years old     2021    14
# 68149     2 years old     2023     1

# %%
df_raw = df_raw.dropna(subset=["Provinces", "Municipalities", "Total"], how="any")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[125], line 1
# ----> 1 df_raw = df_raw.dropna(subset=["Provinces", "Municipalities", "Total"], how="any")
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\frame.py:6435, in DataFrame.dropna(self, axis, how, thresh, subset, inplace, ignore_index)
#    6433     result = self.copy(deep=None)
#    6434 else:
# -> 6435     result = self.loc(axis=axis)[mask]
#    6437 if ignore_index:
#    6438     result.index = default_index(len(result))
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\indexing.py:1325, in _LocIndexer._getitem_axis(self, key, axis)
#    1323     return self._get_slice_axis(key, axis=axis)
#    1324 elif com.is_bool_indexer(key):
# -> 1325     return self._getbool_axis(key, axis=axis)
#    1326 elif is_list_like_indexer(key):
#    1327     # an iterable multi-selection
#    1328     if not (isinstance(key, tuple) and isinstance(labels, MultiIndex)):
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\indexing.py:1123, in _LocationIndexer._getbool_axis(self, key, axis)
#    1121 key = check_bool_indexer(labels, key)
#    1122 inds = key.nonzero()[0]
# -> 1123 return self.obj._take_with_is_copy(inds, axis=axis)
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\generic.py:3948, in NDFrame._take_with_is_copy(self, indices, axis)
#    3940 def _take_with_is_copy(self: NDFrameT, indices, axis: Axis = 0) -> NDFrameT:
#    3941     """
#    3942     Internal version of the `take` method that sets the `_is_copy`
#    3943     attribute to keep track of the parent dataframe (using in indexing
#    (...)
#    3946     See the docstring of `take` for full explanation of the parameters.
#    3947     """
# -> 3948     result = self._take(indices=indices, axis=axis)
#    3949     # Maybe set copy if we didn't actually change the index.
#    3950     if not result._get_axis(axis).equals(self._get_axis(axis)):
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\generic.py:3932, in NDFrame._take(self, indices, axis, convert_indices)
#    3924     if (
#    3925         axis == 0
#    3926         and indices.ndim == 1
#    3927         and using_copy_on_write()
#    3928         and is_range_indexer(indices, len(self))
#    3929     ):
#    3930         return self.copy(deep=None)
# -> 3932 new_data = self._mgr.take(
#    3933     indices,
#    3934     axis=self._get_block_manager_axis(axis),
#    3935     verify=True,
#    3936     convert_indices=convert_indices,
#    3937 )
#    3938 return self._constructor(new_data).__finalize__(self, method="take")
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\managers.py:963, in BaseBlockManager.take(self, indexer, axis, verify, convert_indices)
#     960     indexer = maybe_convert_indices(indexer, n, verify=verify)
#     962 new_labels = self.axes[axis].take(indexer)
# --> 963 return self.reindex_indexer(
#     964     new_axis=new_labels,
#     965     indexer=indexer,
#     966     axis=axis,
#     967     allow_dups=True,
#     968     copy=None,
#     969 )
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\managers.py:747, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
# --> 747     new_blocks = [
#     748         blk.take_nd(
#     749             indexer,
#     750             axis=1,
#     751             fill_value=(
#     752                 fill_value if fill_value is not None else blk.fill_value
#     753             ),
#     754         )
#     755         for blk in self.blocks
#     756     ]
#     758 new_axes = list(self.axes)
#     759 new_axes[axis] = new_axis
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\managers.py:748, in <listcomp>(.0)
#     740     new_blocks = self._slice_take_blocks_ax0(
#     741         indexer,
#     742         fill_value=fill_value,
#     743         only_slice=only_slice,
#     744         use_na_proxy=use_na_proxy,
#     745     )
#     746 else:
#     747     new_blocks = [
# --> 748         blk.take_nd(
#     749             indexer,
#     750             axis=1,
#     751             fill_value=(
#     752                 fill_value if fill_value is not None else blk.fill_value
#     753             ),
#     754         )
#     755         for blk in self.blocks
#     756     ]
#     758 new_axes = list(self.axes)
#     759 new_axes[axis] = new_axis
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\blocks.py:960, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#     957 if new_mgr_locs is None:
#     958     new_mgr_locs = self._mgr_locs
# --> 960 if not is_dtype_equal(new_values.dtype, self.dtype):
#     961     return self.make_block(new_values, new_mgr_locs)
#     962 else:
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\dtypes\common.py:551, in is_dtype_equal(source, target)
#     546             return False
#     548     return _is_dtype(arr_or_dtype, condition)
# --> 551 def is_dtype_equal(source, target) -> bool:
#     552     """
#     553     Check if two dtypes are equal.
#     554
#    (...)
#     576     False
#     577     """
#     578     if isinstance(target, str):
#
# KeyboardInterrupt:

# %%
df_2024 = df_raw[df_raw['Periodo'] == 2024].copy()

# %%
df_2024.reset_index(drop=True, inplace=True)

# %%
idx = pd.Index(["Provinces", "Municipalities", "Sex", "Age", "Periodo", "Total"])
eng = pd.Index(["province", "municipality", "sex", "age", "year", "total"])

df_2024.rename(columns=dict(zip(idx, eng)), inplace=True)

# %% [markdown]
# ### Get the correct types

# %%
df_2024["total"] = pd.to_numeric(df_2024["total"].str.replace(".", "", regex=False)).astype("int32")

# %%
df_2024 = df_2024[df_2024["age"] != "All ages"]

# %%
(df_2024["age"].str.contains(r"^\d"))
# Out:
# 1          True
# 2          True
# 3          True
# 4          True
# 5          True
#            ...
# 2488387    True
# 2488388    True
# 2488389    True
# 2488390    True
# 2488391    True
# Name: age, Length: 2463996, dtype: bool

# %%
df_2024.head()
# Out:
#          province            municipality    sex          age  year  total
# 1  01 Araba/Álava  01001 Alegría-Dulantzi  Males  0 years old  2024     11
# 2  01 Araba/Álava  01001 Alegría-Dulantzi  Males   1 year old  2024      9
# 3  01 Araba/Álava  01001 Alegría-Dulantzi  Males  2 years old  2024     15
# 4  01 Araba/Álava  01001 Alegría-Dulantzi  Males  3 years old  2024     12
# 5  01 Araba/Álava  01001 Alegría-Dulantzi  Males  4 years old  2024      9

# %%
from scripts.utils import split_column_at
df_2024["age"] = split_column_at(df_2024, "age", " ", index=0)
df_2024["province"] = split_column_at(df_2024, "province", " ", index=1)
df_2024["cprov"] = split_column_at(df_2024, "province", " ", index=0)
df_2024["cmun"] = split_column_at(df_2024, "municipality", " ", index=0)
df_2024["municipality"] = split_column_at(df_2024, "municipality", " ", index=1)

# %%
df_2024
# Out:
#             province      municipality    sex  age  year  total        cprov
# 1        Araba/Álava  Alegría-Dulantzi  Males    0  2024     11  Araba/Álava  \
# 2        Araba/Álava  Alegría-Dulantzi  Males    1  2024      9  Araba/Álava
# 3        Araba/Álava  Alegría-Dulantzi  Males    2  2024     15  Araba/Álava
# 4        Araba/Álava  Alegría-Dulantzi  Males    3  2024     12  Araba/Álava
# 5        Araba/Álava  Alegría-Dulantzi  Males    4  2024      9  Araba/Álava
# ...              ...               ...    ...  ...   ...    ...          ...
# 2488387      Melilla           Melilla  Total   96  2024     19      Melilla
# 2488388      Melilla           Melilla  Total   97  2024     13      Melilla
# 2488389      Melilla           Melilla  Total   98  2024     11      Melilla
# 2488390      Melilla           Melilla  Total   99  2024      3      Melilla
# 2488391      Melilla           Melilla  Total  100  2024     12      Melilla
#
#           cmun
# 1        01001
# 2        01001
# 3        01001
# 4        01001
# 5        01001
# ...        ...
# 2488387  52001
# 2488388  52001
# 2488389  52001
# 2488390  52001
# 2488391  52001
#
# [2463996 rows x 8 columns]

# %%
df_2024.drop("cprov", axis = 1, inplace=True)

# %%
df_2024["age"] = pd.to_numeric(df_2024["age"].str.replace(".", "", regex=False)).astype("int32")

# %%
cleaner = AccentCleaner([df_2024], ['municipality', 'province'])
cleaner.cleanAccents()

# %%
df_2024.sample(10)
# Out:
#           province municipality      sex  age  year  total   cmun
# 725780      Cuenca        Valle    Total   49  2024      2  16173  \
# 2369008     Zamora     Pueblica    Total   57  2024      1  49167
# 1303350       Lugo        Ourol    Males   95  2024      3  27038
# 1969408  Tarragona     Margalef    Total   93  2024      2  43075
# 1123127       León      Ercina,  Females    4  2024      0  24068
# 542569       Cádiz      Barbate    Males   30  2024    131  11007
# 1965611  Tarragona      Galera,  Females   70  2024      8  43063
# 489524     Cáceres        Casas    Total   25  2024      3  10056
# 2039052     Teruel       Libros  Females   71  2024      0  44135
# 1575715   Palencia        Olmos  Females   18  2024      1  34114
#
#         municipality_clean province_clean
# 725780               valle         cuenca
# 2369008           pueblica         zamora
# 1303350              ourol           lugo
# 1969408           margalef      tarragona
# 1123127            ercina,           leon
# 542569             barbate          cadiz
# 1965611            galera,      tarragona
# 489524               casas        caceres
# 2039052             libros         teruel
# 1575715              olmos       palencia

# %%
df_2024["province"] = split_column_at(df_2024, "province", " ", index=0)

# %%
df_2024["cmun"] = pd.to_numeric(df_2024["cmun"].str.replace(".", "", regex=False)).astype("int32")

# %%
df_2024.sample(10)
# Out:
#           province municipality      sex  age  year  total   cmun
# 1166710       León  Villaturiel    Total   33  2024     17  24227  \
# 2294260    Bizkaia    Karrantza  Females   75  2024     22  48022
# 184056       Ávila     Tiemblo,  Females   47  2024     23   5241
# 347791   Barcelona    Talamanca  Females   72  2024      3   8277
# 1917660      Soria     Hinojosa    Total   59  2024      1  42100
# 1685783  Salamanca      Mancera    Males   28  2024      0  37179
# 304214   Barcelona    Montmaneu    Males   49  2024      1   8133
# 1283621     Rioja,   Torrecilla    Total   52  2024      0  26152
# 362573      Burgos       Anguix    Total   64  2024      1   9017
# 1032061     Huesca     Canfranc    Total   24  2024     10  22078
#
#         municipality_clean province_clean
# 1166710        villaturiel           leon
# 2294260          karrantza        bizkaia
# 184056            tiemblo,          avila
# 347791           talamanca      barcelona
# 1917660           hinojosa          soria
# 1685783            mancera      salamanca
# 304214           montmaneu      barcelona
# 1283621         torrecilla         rioja,
# 362573              anguix         burgos
# 1032061           canfranc         huesca

# %% [markdown]
# ## Grouping

# %%
df_ages_bined = pd.read_csv("../data/large_files/filtered_age.csv")

# %%
df_demographics = df_ages_bined.query("sex != 'Total'")

# %%
df_demographics.isna().sum()
# Out:
# province                0
# municipality          202
# sex                     0
# age                     0
# year                    0
# total                   0
# cmun                    0
# municipality_clean      0
# province_clean          0
# dtype: int64

# %%
def assign_age_group(age):
    if age <= 17:
        return '0-17'
    elif age <= 24:
        return '18-24'
    elif age <= 34:
        return '25-34'
    elif age <= 54:
        return '35-54'
    else:
        return '55+'

df_demographics['age_group'] = df_demographics['age'].apply(assign_age_group)
# Out:
# C:\Users\Marina\AppData\Local\Temp\ipykernel_24676\3734956762.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_demographics['age_group'] = df_demographics['age'].apply(assign_age_group)

# %%
df_demographics["age_group"].unique()
# Out:
# array(['0-17', '18-24', '25-34', '35-54', '55+'], dtype=object)

# %%
# 2. Pivot the table to have one column per age group
#    We group by 'cmun' (or whichever municipality identifier you prefer)
pivot_df = df_demographics.pivot_table(
    index='cmun',
    columns='age_group',
    values='total',
    aggfunc='sum',
    fill_value=0  # fill missing combinations with 0
).reset_index()

# %%
age_group_order = ['0-17', '18-24', '25-34', '35-54', '55+']
pivot_df = pivot_df[['cmun'] + [grp for grp in age_group_order if grp in pivot_df.columns]]
pivot_df["total_population"] = pivot_df["0-17"] + pivot_df["18-24"] + pivot_df["25-34"] + pivot_df["35-54"] + pivot_df["55+"]

pivot_df
# Out:
# age_group   cmun   0-17  18-24  25-34  35-54    55+  total_population
# 0           1001    615    250    268   1005    827              2965
# 1           1002   1826    588    862   2961   4075             10312
# 2           1003    218    113    108    349    592              1380
# 3           1004    352    127    146    576    655              1856
# 4           1006     42     20     18     96     70               246
# ...          ...    ...    ...    ...    ...    ...               ...
# 8127       50901      6      8     16     37    103               170
# 8128       50902      4      2      4     33     42                85
# 8129       50903    405    224    320    789   1114              2852
# 8130       51001  18151   8386  10785  23963  21894             83179
# 8131       52001  21086   8706  11696  23407  21090             85985
#
# [8132 rows x 7 columns]

# %%
pivot_df_sex = df_demographics.pivot_table(
    index='cmun',
    columns='sex',
    values='total',
    aggfunc='sum',
    fill_value=0  # fill missing combinations with 0
).reset_index()

# %%
df_demographics["sex"].unique()
# Out:
# array(['Males', 'Females'], dtype=object)

# %%
sex_group_order = ['Males', 'Females']

pivot_df_sex = pivot_df_sex[['cmun'] + [grp for grp in sex_group_order if grp in pivot_df_sex.columns]]
pivot_df_sex.rename(columns={"Males": "male", "Females": "female"}, inplace=True)

pivot_df_sex["total_sex"] = pivot_df_sex["male"] + pivot_df_sex["female"]
pivot_df_sex
# Out:
# sex    cmun   male  female  total_sex
# 0      1001   1525    1440       2965
# 1      1002   5134    5178      10312
# 2      1003    709     671       1380
# 3      1004    914     942       1856
# 4      1006    127     119        246
# ...     ...    ...     ...        ...
# 8127  50901    104      66        170
# 8128  50902     43      42         85
# 8129  50903   1444    1408       2852
# 8130  51001  41957   41222      83179
# 8131  52001  43252   42733      85985
#
# [8132 rows x 4 columns]

# %%
df_demographics_combined = pivot_df.merge(df_demographics, on='cmun', how='left')
df_demographics_combined = pivot_df_sex.merge(df_demographics_combined, on='cmun', how='left')

df_demographics_combined
# Out:
#           cmun   male  female  total_sex   0-17  18-24  25-34  35-54    55+
# 0         1001   1525    1440       2965    615    250    268   1005    827  \
# 1         1001   1525    1440       2965    615    250    268   1005    827
# 2         1001   1525    1440       2965    615    250    268   1005    827
# 3         1001   1525    1440       2965    615    250    268   1005    827
# 4         1001   1525    1440       2965    615    250    268   1005    827
# ...        ...    ...     ...        ...    ...    ...    ...    ...    ...
# 1642659  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642660  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642661  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642662  52001  43252   42733      85985  21086   8706  11696  23407  21090
# 1642663  52001  43252   42733      85985  21086   8706  11696  23407  21090
#
#          total_population     province      municipality  year
# 0                    2965  Araba/Álava  Alegría-Dulantzi  2024  \
# 1                    2965  Araba/Álava  Alegría-Dulantzi  2024
# 2                    2965  Araba/Álava  Alegría-Dulantzi  2024
# 3                    2965  Araba/Álava  Alegría-Dulantzi  2024
# 4                    2965  Araba/Álava  Alegría-Dulantzi  2024
# ...                   ...          ...               ...   ...
# 1642659             85985      Melilla           Melilla  2024
# 1642660             85985      Melilla           Melilla  2024
# 1642661             85985      Melilla           Melilla  2024
# 1642662             85985      Melilla           Melilla  2024
# 1642663             85985      Melilla           Melilla  2024
#
#         municipality_clean province_clean
# 0         alegria-dulantzi    araba/alava
# 1         alegria-dulantzi    araba/alava
# 2         alegria-dulantzi    araba/alava
# 3         alegria-dulantzi    araba/alava
# 4         alegria-dulantzi    araba/alava
# ...                    ...            ...
# 1642659            melilla        melilla
# 1642660            melilla        melilla
# 1642661            melilla        melilla
# 1642662            melilla        melilla
# 1642663            melilla        melilla
#
# [1642664 rows x 15 columns]

# %%
df_demographics_combined = df_demographics_combined.drop(["year", "municipality", "province", "total_sex"], axis = 1)

# %%
df_demographics_combined
# Out:
#           cmun   male  female   0-17  18-24  25-34  35-54    55+
# 0         1001   1525    1440    615    250    268   1005    827  \
# 1         1001   1525    1440    615    250    268   1005    827
# 2         1001   1525    1440    615    250    268   1005    827
# 3         1001   1525    1440    615    250    268   1005    827
# 4         1001   1525    1440    615    250    268   1005    827
# ...        ...    ...     ...    ...    ...    ...    ...    ...
# 1642659  52001  43252   42733  21086   8706  11696  23407  21090
# 1642660  52001  43252   42733  21086   8706  11696  23407  21090
# 1642661  52001  43252   42733  21086   8706  11696  23407  21090
# 1642662  52001  43252   42733  21086   8706  11696  23407  21090
# 1642663  52001  43252   42733  21086   8706  11696  23407  21090
#
#          total_population municipality_clean province_clean
# 0                    2965   alegria-dulantzi    araba/alava
# 1                    2965   alegria-dulantzi    araba/alava
# 2                    2965   alegria-dulantzi    araba/alava
# 3                    2965   alegria-dulantzi    araba/alava
# 4                    2965   alegria-dulantzi    araba/alava
# ...                   ...                ...            ...
# 1642659             85985            melilla        melilla
# 1642660             85985            melilla        melilla
# 1642661             85985            melilla        melilla
# 1642662             85985            melilla        melilla
# 1642663             85985            melilla        melilla
#
# [1642664 rows x 11 columns]

# %%
df_demographics_combined = df_demographics_combined[["cmun", "municipality_clean", "province_clean", "0-17", "18-24", "25-34", "35-54","55+", "male", "female","total_population"]]

# %%
df_demographics_combined
# Out:
#           cmun municipality_clean province_clean   0-17  18-24  25-34  35-54
# 0         1001   alegria-dulantzi    araba/alava    615    250    268   1005  \
# 1         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# 2         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# 3         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# 4         1001   alegria-dulantzi    araba/alava    615    250    268   1005
# ...        ...                ...            ...    ...    ...    ...    ...
# 1642659  52001            melilla        melilla  21086   8706  11696  23407
# 1642660  52001            melilla        melilla  21086   8706  11696  23407
# 1642661  52001            melilla        melilla  21086   8706  11696  23407
# 1642662  52001            melilla        melilla  21086   8706  11696  23407
# 1642663  52001            melilla        melilla  21086   8706  11696  23407
#
#            55+   male  female  total_population
# 0          827   1525    1440              2965
# 1          827   1525    1440              2965
# 2          827   1525    1440              2965
# 3          827   1525    1440              2965
# 4          827   1525    1440              2965
# ...        ...    ...     ...               ...
# 1642659  21090  43252   42733             85985
# 1642660  21090  43252   42733             85985
# 1642661  21090  43252   42733             85985
# 1642662  21090  43252   42733             85985
# 1642663  21090  43252   42733             85985
#
# [1642664 rows x 11 columns]

# %%
df_demographics_combined = df_demographics_combined.drop_duplicates()
df_demographics_combined
# Out:
#           cmun municipality_clean province_clean   0-17  18-24  25-34  35-54
# 0         1001   alegria-dulantzi    araba/alava    615    250    268   1005  \
# 202       1002            amurrio    araba/alava   1826    588    862   2961
# 404       1003            aramaio    araba/alava    218    113    108    349
# 606       1004         artziniega    araba/alava    352    127    146    576
# 808       1006            arminon    araba/alava     42     20     18     96
# ...        ...                ...            ...    ...    ...    ...    ...
# 1641654  50901               biel       zaragoza      6      8     16     37
# 1641856  50902           marracos       zaragoza      4      2      4     33
# 1642058  50903         villamayor       zaragoza    405    224    320    789
# 1642260  51001              ceuta          ceuta  18151   8386  10785  23963
# 1642462  52001            melilla        melilla  21086   8706  11696  23407
#
#            55+   male  female  total_population
# 0          827   1525    1440              2965
# 202       4075   5134    5178             10312
# 404        592    709     671              1380
# 606        655    914     942              1856
# 808         70    127     119               246
# ...        ...    ...     ...               ...
# 1641654    103    104      66               170
# 1641856     42     43      42                85
# 1642058   1114   1444    1408              2852
# 1642260  21894  41957   41222             83179
# 1642462  21090  43252   42733             85985
#
# [8132 rows x 11 columns]

# %%
df_demographics_combined.to_csv("../data/processed/filtered_demographics.csv", index=False)
