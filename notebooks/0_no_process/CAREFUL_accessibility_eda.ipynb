# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '../..')))

import pandas as pd
import numpy as np
from geopy.distance import geodesic
from scripts.locator import Locator
# Out:
# INFO: Pandarallel will run on 4 workers.
# INFO: Pandarallel will use standard multiprocessing data transfer (pipe) to transfer data between the main process and workers.
#
# WARNING: You are on Windows. If you detect any issue with pandarallel, be sure you checked out the Troubleshooting page:
# https://nalepae.github.io/pandarallel/troubleshooting/

# %% [markdown]
# ### accessibility score:
# - distance to airport
# - distance to train stations
# - altitude?

# %%
df_municipalities = pd.read_csv("../../data/processed/filtered_files/filtered_municipalities.csv")
df_airports = pd.read_csv("../../data/processed/filtered_files/filtered_airports.csv")
df_railway = pd.read_csv("../../data/processed/filtered_files/filtered_trains.csv")

# %%
df_municipalities.head()
# Out:
#    cmun      municipality   municipality_1 municipality_2 province  \
# 0  1001  Alegría-Dulantzi  alegriadulantzi            NaN    Álava
# 1  1002           Amurrio          amurrio            NaN    Álava
# 2  1003           Aramaio          aramaio            NaN    Álava
# 3  1004        Artziniega       artziniega            NaN    Álava
# 4  1006           Armiñón          arminon            NaN    Álava
#
#   autonomous_community  latitude  longitude  altitude
# 0           País Vasco  42.84149  -2.513507  561.6857
# 1           País Vasco  43.05265  -3.001022  219.6910
# 2           País Vasco  43.05400  -2.566000  381.8797
# 3           País Vasco  43.12220  -3.128209  196.9808
# 4           País Vasco  42.72305  -2.872574  463.5815

# %%
df_airports.head()
# Out:
#                            airport   latitude  longitude  y_passengers  \
# 0   Adolfo Suárez Madrid - Barajas  40.492080  -3.576319      60220984
# 1                         Albacete  38.949634  -1.863164          2644
# 2  Alicante-Elche Miguel Hernández  38.285826  -0.563349      15747678
# 3                          Almería  36.844781  -2.371234        775393
# 4                         Asturias  43.562196  -6.032618       1974850
#
#    scaled_size
# 0  752762.3000
# 1      33.0500
# 2  196845.9750
# 3    9692.4125
# 4   24685.6250

# %%
df_railway.sample(15)
# Out:
#      station_code                station_name   latitude  longitude  \
# 315         54403  El Chorro-Caminito Del Rey  36.907317  -4.759240
# 218         74205             Riglos-Concilio  42.316965  -0.727418
# 285         20218            Pobra De Brollon  42.533752  -7.400153
# 503         35005                    Illescas  40.120872  -3.842335
# 377         23004                  Pontevedra  42.421640  -8.635830
# 430         82100                       Soria  41.755282  -2.475496
# 389         23008        Vilagarcia De Arousa  42.601975  -8.762266
# 524         69003            La Pobla Del Duc  38.915336  -0.445484
# 413         33013              Ciudad Rodrigo  40.608735  -6.530465
# 489         67103       Villafranca Del Campo  40.684065  -1.357900
# 127         20320                Oza Dos Rios  43.218716  -8.187044
# 412         32007                    Pitiegua  41.063766  -5.474106
# 259         20100                     Astorga  42.459417  -6.047173
# 443         73006            Vimbodi I Poblet  41.402695   1.045990
# 330         81203                  Ribaforada  41.997098  -1.515225
#
#               municipality           province
# 315                  Álora             málaga
# 218   Peñas De Riglos, Las             huesca
# 285    Pobra Do Brollón, A               lugo
# 503               Illescas             toledo
# 377             Pontevedra         pontevedra
# 430                  Soria              soria
# 389   Vilagarcía De Arousa         pontevedra
# 524      Pobla Del Duc, La  valencia/valéncia
# 413         Ciudad Rodrigo          salamanca
# 489  Villafranca Del Campo             teruel
# 127            Oza-Cesuras          coruña, a
# 412               Pitiegua          salamanca
# 259                Astorga               león
# 443       Vimbodí I Poblet          tarragona
# 330             Ribaforada            navarra

# %%
# Apply the function to each row in the towns DataFrame and create two new columns
df_municipalities[['closest_distance_airport', 'nearest_airport']] = Locator(df_municipalities, df_airports, 'airport_name').result
df_municipalities[['closest_distance_train', 'nearest_train_station']]  = Locator(df_municipalities, df_railway, 'station_name').result

# %%
df_accessibility = df_municipalities[["cmun", "municipality_name", "province", "altitude", "longitude", "latitude", "nearest_airport", "closest_distance_airport", "nearest_train_station", "closest_distance_train"]]

# %%
# df_municipalities = pd.read_csv("../data/processed/filtered_municipalities.csv")
# df_accessibility = pd.read_csv("../../data/scored/accessibility.csv")
df_hospitals = pd.read_csv("../../data/processed/filtered_hospitals.csv")

# %%
df_accessibility = df_accessibility[["cmun", "municipality_name", "province", "altitude", "longitude", "latitude", "nearest_airport", "closest_distance_airport", "nearest_train_station", "closest_distance_train"]]
df_hospitals_general = df_hospitals.query("type == 'General'")

# Apply the function to each row in the towns DataFrame and create two new columns
df_accessibility[['closest_distance_hospital', 'nearest_hospital']] = Locator(df_accessibility, df_hospitals_general, 'hospital_name').result

# %%
df_schools = pd.read_csv("../../data/processed/filtered_schools.csv")
df_distances = pd.read_csv("../../data/processed/processed_distances.csv")
df_schools
# Out:
#        school_id public_private  \
# 0              1         Public
# 1              2         Public
# 2              3         Public
# 3              4         Public
# 4              5         Public
# ...          ...            ...
# 26601      26602         Public
# 26602      26603         Public
# 26603      26604         Public
# 26604      26605         Public
# 26605      26606         Public
#
#                                                     type  \
# 0      Colegio público de educación infantil y primar...
# 1                              Escuela pública de música
# 2                                       Escuela infantil
# 3               Colegio de educación infantil y primaria
# 4               Colegio de educación infantil y primaria
# ...                                                  ...
# 26601            Aula de educación permanente de adultos
# 26602            Aula de educación permanente de adultos
# 26603          Centro de educación permanente de adultos
# 26604          Centro de educación permanente de adultos
# 26605          Centro de educación permanente de adultos
#
#                                     name   latitude  longitude
# 0           CPEIP Abarzuza Zumadia HLHIP  42.726290  -2.022176
# 1                 Esc. Mús. Púb. Ablitas  41.975297  -1.640062
# 2                     EI Ablitas Mi Cole  41.974719  -1.641089
# 3           CPEIP Ablitas S. Babil HLHIP  41.974047  -1.641728
# 4      CPEIP Aibar G. V. Casamayor HLHIP  42.590753  -1.361802
# ...                                  ...        ...        ...
# 26601         A.E.P.A. Herrera del Duque  39.168134  -5.048491
# 26602               A.E.P.A. Madrigalejo  39.135204  -5.626350
# 26603                     C.E.P.A. Coria  39.987626  -6.538688
# 26604                 C.E.P.A. Talayuela  39.982802  -5.607226
# 26605         C.E.P.A. Jaraíz de la Vera  40.062074  -5.751735
#
# [26606 rows x 6 columns]

# %%
df_schools_filtered = df_schools.dropna(subset=['latitude', 'longitude'])
df_distances[['closest_distance_school', 'nearest_school']] = Locator(df_distances, df_schools_filtered, 'name').result

# %%
# df_accessibility.to_csv("../../data/processed/processed_distances.csv", index=False)
df_distances.to_csv("../../data/processed/filtered_files/processed_distances.csv", index=False)
