# %% [markdown]
# ## Geographical Data and Main Information of Municipalities

# %% [markdown]
# ### Main notes
#
# * We have had a lot of problems when matching different languages
# * From the original dataset, we have lost 97 municipalities that we weren't able to match with coordinates.
# * We have dropped Population data from this dataset, as it will be covered in a different notebook (demographics)

# %%
import sys
import os
import re
from unidecode import unidecode

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))

import pandas as pd
import plotly.express as px
import numpy as np

from scripts.accent_cleaner import AccentCleaner
from scripts.column_aligner import ColumnAligner
from scripts.utils import split_at_char, replace_with

# %%
df_municipalities = pd.read_csv(
    "../data/raw/population_towns.csv", 
    encoding="ISO-8859-1",  # or "latin1",
    sep=";",
    decimal=",")
df_municipalities_coordinates = pd.read_csv(
    "../data/raw/coordinates_towns_spain.csv",
    encoding="ISO-8859-1",  # or "latin1"
    sep=";",
    decimal=","
)

# %%
df_municipalities.shape
# Out:
# (8132, 7)

# %%
df_municipalities_coordinates.shape
# Out:
# (8112, 9)

# %%
df_municipalities.rename(columns={
                          "PROVINCIA": "province",
                          "NOMBRE": "municipality",
                          "POB24": "population",
                          "MUJERES": "female",
                          "HOMBRES": "male" }, inplace=True)

# %%
df_municipalities_coordinates.rename(columns={"Comunidad": "autonomous_community",
                          "Provincia": "province",
                            "Población": "municipality",
                          "Habitantes": "population",
                            "Hombres": "male",
                            "Mujeres": "female",
                          "Latitud": "latitude",
                          "Longitud": "longitude",
                          "Altitud": "altitude" }, inplace=True)

# %%
df_municipalities = df_municipalities.drop(["population", "female", "male"], axis = 1)
df_municipalities_coordinates = df_municipalities_coordinates.drop(["population", "female", "male"], axis = 1)

# %%
df_municipalities_coordinates = replace_with(df_municipalities_coordinates, 'province', 'Vizcaya', 'Bizkaia')
df_municipalities_coordinates = replace_with(df_municipalities_coordinates, 'province', 'Alicante/Alacant', 'Alicante')
df_municipalities_coordinates = replace_with(df_municipalities_coordinates, 'province', 'Castellón/Castelló', 'Castellón')
df_municipalities_coordinates = replace_with(df_municipalities_coordinates, 'province', 'Valencia/València', 'Valencia')
df_municipalities_coordinates = replace_with(df_municipalities_coordinates, 'province', 'Guipúzcoa', 'Gipuzkoa')

# %%
df_municipalities_coordinates = replace_with(df_municipalities_coordinates, 'autonomous_community', 'Catalunya', 'Cataluña')

# %% [markdown]
# # Split columns and clean

# %%
# Split municipality names into two columns
df_municipalities[['municipality_1', 'municipality_2']] = df_municipalities['municipality'].str.split('/', n=1, expand=True)

# Fill missing values in municipality_2 with "none" (as a string)
df_municipalities["municipality_2"] = df_municipalities["municipality_2"].fillna("none")

# %%
#split municipality names into two columns
df_municipalities_coordinates[['municipality_1', 'municipality_2']] = df_municipalities_coordinates['municipality'].str.split('/', n=1, expand=True)

# Fill missing values in municipality_2 with "none" (as a string)
df_municipalities_coordinates["municipality_2"] = df_municipalities_coordinates["municipality_2"].fillna("none")

# %%
# Function to clean a column (remove accents, normalize case)
def clean_column(column):
    return column.apply(lambda x: unidecode(str(x)).strip().lower() if pd.notna(x) else x)

# Apply cleaning to df_municipalities
df_municipalities["municipality_1"] = clean_column(df_municipalities["municipality_1"])
df_municipalities["municipality_2"] = clean_column(df_municipalities["municipality_2"])

# Apply cleaning to df_municipalities_coordinates
df_municipalities_coordinates["municipality_1"] = clean_column(df_municipalities_coordinates["municipality_1"])
df_municipalities_coordinates["municipality_2"] = clean_column(df_municipalities_coordinates["municipality_2"])

# %%
df_municipalities['municipality_1'] = df_municipalities['municipality_1'].str.replace(" ","")
df_municipalities['municipality_1'] = df_municipalities['municipality_1'].str.replace(",","")
df_municipalities['municipality_1'] = df_municipalities['municipality_1'].str.replace("(","")
df_municipalities['municipality_1'] = df_municipalities['municipality_1'].str.replace(")","")
df_municipalities['municipality_1'] = df_municipalities['municipality_1'].str.replace("-","")
df_municipalities['municipality_1'] = df_municipalities['municipality_1'].str.replace("ñ","n")

df_municipalities['municipality_2'] = df_municipalities['municipality_2'].str.replace(" ","")
df_municipalities['municipality_2'] = df_municipalities['municipality_2'].str.replace(",","")
df_municipalities['municipality_2'] = df_municipalities['municipality_2'].str.replace("(","")
df_municipalities['municipality_2'] = df_municipalities['municipality_2'].str.replace(")","")
df_municipalities['municipality_2'] = df_municipalities['municipality_2'].str.replace("-","")
df_municipalities['municipality_2'] = df_municipalities['municipality_2'].str.replace("ñ","n")

# %%
df_municipalities_coordinates['municipality_1'] = df_municipalities_coordinates['municipality_1'].str.replace(" ","")
df_municipalities_coordinates['municipality_1'] = df_municipalities_coordinates['municipality_1'].str.replace(",","")
df_municipalities_coordinates['municipality_1'] = df_municipalities_coordinates['municipality_1'].str.replace("(","")
df_municipalities_coordinates['municipality_1'] = df_municipalities_coordinates['municipality_1'].str.replace(")","")
df_municipalities_coordinates['municipality_1'] = df_municipalities_coordinates['municipality_1'].str.replace("-","")
df_municipalities_coordinates['municipality_1'] = df_municipalities_coordinates['municipality_1'].str.replace("ñ","n")

df_municipalities_coordinates['municipality_2'] = df_municipalities_coordinates['municipality_2'].str.replace(" ","")
df_municipalities_coordinates['municipality_2'] = df_municipalities_coordinates['municipality_2'].str.replace(",","")
df_municipalities_coordinates['municipality_2'] = df_municipalities_coordinates['municipality_2'].str.replace("(","")
df_municipalities_coordinates['municipality_2'] = df_municipalities_coordinates['municipality_2'].str.replace(")","")
df_municipalities_coordinates['municipality_2'] = df_municipalities_coordinates['municipality_2'].str.replace("-","")
df_municipalities_coordinates['municipality_2'] = df_municipalities_coordinates['municipality_2'].str.replace("ñ","n")

# %% [markdown]
# # Merging DFs

# %%
df_municipalities.loc[df_municipalities["municipality_2"].isna(), "language"] = "language"
df_municipalities_coordinates.loc[df_municipalities_coordinates["municipality_2"].isna(), "language"] = "language"

# %%
merge_1 = df_municipalities.merge(df_municipalities_coordinates, on = "municipality_1", how="left")

# %%
merge_1 = merge_1.dropna(subset=['latitude'])

# %%
merge_2 = df_municipalities.merge(df_municipalities_coordinates, left_on="municipality_1", right_on="municipality_2", how="left")

# %%
merge_2 = merge_2.dropna(subset=['latitude'])

# %%
merged_df = pd.concat([merge_1, merge_2])

# %%
merged_df.shape
# Out:
# (8069, 17)

# %%
merged_df.isna().sum()
# Out:
# CPRO                       0
# province_x                 0
# CMUN                       0
# municipality_x             0
# municipality_1            28
# municipality_2_x           0
# language_x              8069
# autonomous_community       0
# province_y                 0
# municipality_y             0
# latitude                   0
# longitude                  0
# altitude                   0
# municipality_2_y           0
# language_y              8069
# municipality_1_x        8041
# municipality_1_y        8041
# dtype: int64

# %%
merged_df.shape
# Out:
# (8069, 17)

# %%
merge_3 = df_municipalities.merge(df_municipalities_coordinates, left_on="municipality_2", right_on="municipality_1", how="left")

# %%
merge_3 = merge_3.dropna(subset=['latitude'])

# %%
merged_df = pd.concat([merged_df, merge_3])

# %%
merged_df.shape
# Out:
# (8099, 17)

# %%
merged_df.isna().sum()
# Out:
# CPRO                       0
# province_x                 0
# CMUN                       0
# municipality_x             0
# municipality_1            58
# municipality_2_x           0
# language_x              8099
# autonomous_community       0
# province_y                 0
# municipality_y             0
# latitude                   0
# longitude                  0
# altitude                   0
# municipality_2_y           0
# language_y              8099
# municipality_1_x        8041
# municipality_1_y        8041
# dtype: int64

# %%
df_municipalities_coordinates = df_municipalities_coordinates[df_municipalities_coordinates["municipality_2"] != "none"]
df_municipalities = df_municipalities[df_municipalities["municipality_2"] != "none"]

# %%
# Perform merges on all combinations
merge_4 = df_municipalities.merge(df_municipalities_coordinates, left_on="municipality_2", right_on="municipality_2", how="left")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[109], line 2
#       1 # Perform merges on all combinations
# ----> 2 merge_4 = df_municipalities.merge(df_municipalities_coordinates, left_on="municipality_2", right_on="municipality_2", how="left")
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\frame.py:10832, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10813 @Substitution("")
#   10814 @Appender(_merge_doc, indents=2)
#   10815 def merge(
#    (...)
#   10828     validate: MergeValidate | None = None,
#   10829 ) -> DataFrame:
#   10830     from pandas.core.reshape.merge import merge
# > 10832     return merge(
#   10833         self,
#   10834         right,
#   10835         how=how,
#   10836         on=on,
#   10837         left_on=left_on,
#   10838         right_on=right_on,
#   10839         left_index=left_index,
#   10840         right_index=right_index,
#   10841         sort=sort,
#   10842         suffixes=suffixes,
#   10843         copy=copy,
#   10844         indicator=indicator,
#   10845         validate=validate,
#   10846     )
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\reshape\merge.py:879, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     877 left.columns = llabels
#     878 right.columns = rlabels
# --> 879 result = concat([left, right], axis=1, copy=copy)
#     880 return result
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\reshape\concat.py:395, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380     copy = False
#     382 op = _Concatenator(
#     383     objs,
#     384     axis=axis,
#    (...)
#     392     sort=sort,
#     393 )
# --> 395 return op.get_result()
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\reshape\concat.py:684, in _Concatenator.get_result(self)
#     680             indexers[ax] = obj_labels.get_indexer(new_labels)
#     682     mgrs_indexers.append((obj._mgr, indexers))
# --> 684 new_data = concatenate_managers(
#     685     mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     686 )
#     687 if not self.copy and not using_copy_on_write():
#     688     new_data._consolidate_inplace()
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\concat.py:131, in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     124 # Assertions disabled for performance
#     125 # for tup in mgrs_indexers:
#     126 #    # caller is responsible for ensuring this
#     127 #    indexers = tup[1]
#     128 #    assert concat_axis not in indexers
#     130 if concat_axis == 0:
# --> 131     mgrs = _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     132     return mgrs[0].concat_horizontal(mgrs, axes)
#     134 if len(mgrs_indexers) > 0 and mgrs_indexers[0][0].nblocks > 0:
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\concat.py:230, in _maybe_reindex_columns_na_proxy(axes, mgrs_indexers, needs_copy)
#     220         mgr = mgr.reindex_indexer(
#     221             axes[i],
#     222             indexers[i],
#    (...)
#     227             use_na_proxy=True,  # only relevant for i==0
#     228         )
#     229     if needs_copy and not indexers:
# --> 230         mgr = mgr.copy()
#     232     new_mgrs.append(mgr)
#     233 return new_mgrs
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\managers.py:593, in BaseBlockManager.copy(self, deep)
#     590     else:
#     591         new_axes = list(self.axes)
# --> 593 res = self.apply("copy", deep=deep)
#     594 res.axes = new_axes
#     596 if self.ndim > 1:
#     597     # Avoid needing to re-compute these
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File d:\DS\ml-pueblos\.venv\Lib\site-packages\pandas\core\internals\blocks.py:796, in Block.copy(self, deep)
#     794 refs: BlockValuesRefs | None
#     795 if deep:
# --> 796     values = values.copy()
#     797     refs = None
#     798 else:
#
# KeyboardInterrupt:

# %%
merge_4 = merge_4.dropna(subset=['latitude'])

# %%
# Concatenate results and drop duplicates
merged_df = pd.concat([merge_1, merge_2, merge_3, merge_4])

# %%
merged_df.shape
# Out:
# (32042, 16)

# %%
merged_df.drop_duplicates().shape
# Out:
# (24073, 16)

# %%
merged_df.shape
# Out:
# (32664, 16)

# %%
# Perform merges on all combinations
# merge_1 = df_municipalities.merge(df_municipalities_coordinates, left_on="municipality_1_clean", right_on="municipality_1_clean", how="left")

# %%
# merge_2 = merge_1.merge(df_municipalities_coordinates, left_on="municipality_2_clean_y", right_on="municipality_2_clean", how="left")

# %%
# merge_3 = merge_2.merge(df_municipalities_coordinates, left_on="municipality_1_clean_x", right_on="municipality_2_clean", how="left")

# %%
# merge_4 = df_municipalities.merge(df_municipalities_coordinates, left_on="municipality_2", right_on="municipality_2", how="outer")

# %%
# merged_df = pd.concat([merge_1, merge_2, merge_3, merge_4])

# %%
# merged_df = merged_df.drop_duplicates(subset=['municipality_1_clean'], keep='first')

# %%
# # Show all rows and columns
# pd.set_option('display.max_rows', None)  # Show all rows
# pd.set_option('display.max_columns', None)  # Show all columns
# pd.set_option('display.expand_frame_repr', False)  # Prevent column wrapping


# merged_df[merged_df["latitude"].isna()]

# %%
# df_municipalities_coordinates = df_municipalities_coordinates.drop_duplicates(subset=['municipality_1'], keep='first')

# %%
# Concatenate results and drop duplicates
# merged_df = pd.concat([merge_1, merge_2, merge_3, merge_4]).drop_duplicates().reset_index(drop=True)

# %% [markdown]
# # One by one

# %%
language_provinces = ['Navarra', 'Álava', 'Gipuzkoa', 'Bizkaia', 'Alicante', 'Castellón', 'Valencia']

# %%
# df_municipalities_coordinates.loc[(df_municipalities_coordinates["language"]) & (df_municipalities_coordinates["province"] == "Navarra")]

# %%
# df_municipalities_coordinates.loc[(df_municipalities_coordinates["language"]) & (df_municipalities_coordinates["province"] == "Álava")]

# %%
# df_municipalities_coordinates.loc[(df_municipalities_coordinates["language"]) & (df_municipalities_coordinates["province"] == "Gipuzkoa")]

# %%
# df_municipalities_coordinates.loc[(df_municipalities_coordinates["language"]) & (df_municipalities_coordinates["province"] == "Bizkaia")]

# %%
# df_municipalities_coordinates.loc[(df_municipalities_coordinates["language"]) & (df_municipalities_coordinates["province"] == "Alicante")]

# %%
df_municipalities_coordinates.loc[(df_municipalities_coordinates["province"] == "Castellón")]
# Out:
#      autonomous_community   province                                municipality  latitude  longitude     altitude           municipality_1     municipality_2
# 7711             Valencia  Castellón                                         Aín  39.90086  -0.340800   497.952300                      ain               None
# 7712             Valencia  Castellón                                  Albocàsser  40.35626   0.025362   534.062000               albocasser               None
# 7713             Valencia  Castellón                            Alcalà de Xivert  40.30459   0.226305   159.651600           alcaladexivert               None
# 7714             Valencia  Castellón                                 Alcora (l')  40.07278  -0.213024   274.333600                 alcoral'               None
# 7715             Valencia  Castellón                              Alcudia de Veo  39.91713  -0.355633   476.465600             alcudiadeveo               None
# 7716             Valencia  Castellón                               Alfondeguilla  39.83725  -0.268790   217.893600            alfondeguilla               None
# 7717             Valencia  Castellón                        Algimia de Almonacid  39.91433  -0.443457   496.817300       algimiadealmonacid               None
# 7718             Valencia  Castellón                          Almazora/Almassora  39.94497  -0.063318    37.787060                 almazora          almassora
# 7719             Valencia  Castellón                                   Almedíjar  39.87085  -0.410406   400.144000                almedijar               None
# 7720             Valencia  Castellón                                    Almenara  39.75440  -0.222755    39.321600                 almenara               None
# 7721             Valencia  Castellón                  Alquerías del Niño Perdido  39.89653  -0.113446    25.466890  alqueriasdelninoperdido               None
# 7722             Valencia  Castellón                                      Altura  39.85300  -0.513552   405.551800                   altura               None
# 7723             Valencia  Castellón                                     Arañuel  40.07110  -0.481795   413.379700                  aranuel               None
# 7724             Valencia  Castellón                            Ares del Maestre  40.45699  -0.133407  1193.523000           aresdelmaestre               None
# 7725             Valencia  Castellón                                    Argelita  40.05524  -0.349851   312.053600                 argelita               None
# 7726             Valencia  Castellón                                      Artana  39.89002  -0.257637   256.881800                   artana               None
# 7727             Valencia  Castellón                       Atzeneta del Maestrat  40.21661  -0.170661   405.630200      atzenetadelmaestrat               None
# 7728             Valencia  Castellón                                      Ayódar  39.99977  -0.376051   388.734300                   ayodar               None
# 7729             Valencia  Castellón                                     Azuébar  39.83419  -0.370496   277.036700                  azuebar               None
# 7730             Valencia  Castellón                                    Barracas  40.01577  -0.696706   985.049500                 barracas               None
# 7731             Valencia  Castellón                                       Bejís  39.91087  -0.703868   762.837800                    bejis               None
# 7732             Valencia  Castellón                                     Benafer  39.93554  -0.576751   588.702900                  benafer               None
# 7733             Valencia  Castellón                                   Benafigos  40.27721  -0.209237   932.020300                benafigos               None
# 7734             Valencia  Castellón                                     Benasal  40.37828  -0.137136   839.546600                  benasal               None
# 7735             Valencia  Castellón                                   Benicarló  40.41870   0.423102    17.994880                benicarlo               None
# 7736             Valencia  Castellón                        Benicasim/Benicàssim  40.05554   0.065607    16.668720                benicasim         benicassim
# 7737             Valencia  Castellón                                    Benlloch  40.21074   0.027085   315.553200                 benlloch               None
# 7738             Valencia  Castellón                                       Betxí  39.92623  -0.198169    99.391400                    betxi               None
# 7739             Valencia  Castellón                           Borriana/Burriana  39.88987  -0.083694    20.259900                 borriana           burriana
# 7740             Valencia  Castellón                                     Borriol  40.04169  -0.066421   189.358900                  borriol               None
# 7741             Valencia  Castellón                                     Cabanes  40.15477   0.045430   282.710000                  cabanes               None
# 7742             Valencia  Castellón                                       Càlig  40.46129   0.356657   120.557100                    calig               None
# 7743             Valencia  Castellón                               Canet lo Roig  40.55226   0.244458   327.964100              canetloroig               None
# 7744             Valencia  Castellón                           Castell de Cabres  40.66072   0.042876  1137.328000          castelldecabres               None
# 7745             Valencia  Castellón                                 Castellfort  40.50092  -0.190699  1170.340000              castellfort               None
# 7746             Valencia  Castellón                                 Castellnovo  39.86256  -0.458392   370.467900              castellnovo               None
# 7747             Valencia  Castellón  Castellón de la Plana/Castelló de la Plana  39.98598  -0.037671    36.000000       castellondelaplana  castellodelaplana
# 7748             Valencia  Castellón                     Castillo de Villamalefa  40.13031  -0.378535   817.182700    castillodevillamalefa               None
# 7749             Valencia  Castellón                                        Catí  40.47099   0.022275   663.777200                     cati               None
# 7750             Valencia  Castellón                                     Caudiel  39.94761  -0.567941   635.608500                  caudiel               None
# 7751             Valencia  Castellón                         Cervera del Maestre  40.45456   0.279683   262.361200        cerveradelmaestre               None
# 7752             Valencia  Castellón                                  Chert/Xert  40.51731   0.160406   446.436600                    chert               xert
# 7753             Valencia  Castellón                             Chilches/Xilxes  39.78072  -0.187578     9.052402                 chilches             xilxes
# 7754             Valencia  Castellón                                Chodos/Xodos  40.24561  -0.287507  1044.754000                   chodos              xodos
# 7755             Valencia  Castellón                                      Chóvar  39.85124  -0.320639   416.255600                   chovar               None
# 7756             Valencia  Castellón                                  Cinctorres  40.58369  -0.216539   907.100900               cinctorres               None
# 7757             Valencia  Castellón                                       Cirat  40.05533  -0.463201   390.595900                    cirat               None
# 7758             Valencia  Castellón                           Cortes de Arenoso  40.18552  -0.542617   970.990100          cortesdearenoso               None
# 7759             Valencia  Castellón                                      Costur  40.12006  -0.172886   459.022400                   costur               None
# 7760             Valencia  Castellón                      Coves de Vinromà (les)  40.30804   0.122541   181.389600        covesdevinromales               None
# 7761             Valencia  Castellón                                       Culla  40.33772  -0.165797  1086.087000                    culla               None
# 7762             Valencia  Castellón                                      Eslida  39.88116  -0.306846   346.782300                   eslida               None
# 7763             Valencia  Castellón                                   Espadilla  40.02809  -0.355491   275.297200                espadilla               None
# 7764             Valencia  Castellón                                     Fanzara  40.01797  -0.316918   224.874800                  fanzara               None
# 7765             Valencia  Castellón                                  Figueroles  40.11762  -0.237572   366.596200               figueroles               None
# 7766             Valencia  Castellón                                     Forcall  40.64625  -0.202468   704.904900                  forcall               None
# 7767             Valencia  Castellón                             Fuente la Reina  40.06317  -0.609128   813.203900            fuentelareina               None
# 7768             Valencia  Castellón                           Fuentes de Ayódar  40.02060  -0.420784   505.947000          fuentesdeayodar               None
# 7769             Valencia  Castellón                                     Gaibiel  39.92398  -0.497768   515.278400                  gaibiel               None
# 7770             Valencia  Castellón                                       Geldo  39.83671  -0.466907   304.166300                    geldo               None
# 7771             Valencia  Castellón                                      Herbés  40.72012  -0.003100   756.510200                   herbes               None
# 7772             Valencia  Castellón                                    Higueras  39.98375  -0.503010   668.371600                 higueras               None
# 7773             Valencia  Castellón                                   Jana (la)  39.99738  -0.052744    41.331010                   janala               None
# 7774             Valencia  Castellón                                      Jérica  39.91340  -0.572569   491.427700                   jerica               None
# 7775             Valencia  Castellón                                  Llosa (la)  39.76972  -0.207812    13.798910                  llosala               None
# 7776             Valencia  Castellón                              Lucena del Cid  40.13850  -0.279997   564.106400             lucenadelcid               None
# 7777             Valencia  Castellón                                    Ludiente  40.08733  -0.372298   429.938300                 ludiente               None
# 7778             Valencia  Castellón                        Mata de Morella (la)  40.61561  -0.279067   809.320600          matademorellala               None
# 7779             Valencia  Castellón                                       Matet  39.93716  -0.469438   574.554000                    matet               None
# 7780             Valencia  Castellón                                     Moncofa  39.80862  -0.145778     8.799705                  moncofa               None
# 7781             Valencia  Castellón                                      Montán  40.03509  -0.552754   554.355600                   montan               None
# 7782             Valencia  Castellón                                  Montanejos  40.06796  -0.522737   471.201800               montanejos               None
# 7783             Valencia  Castellón                                     Morella  40.61900  -0.097733   932.552900                  morella               None
# 7784             Valencia  Castellón                                     Navajas  39.87727  -0.505991   389.920400                  navajas               None
# 7785             Valencia  Castellón                                       Nules  39.85245  -0.158631    18.000000                    nules               None
# 7786             Valencia  Castellón                              Olocau del Rey  40.63729  -0.340240  1041.123000             olocaudelrey               None
# 7787             Valencia  Castellón                                        Onda  39.96530  -0.262645   192.792100                     onda               None
# 7788             Valencia  Castellón                      Oropesa del Mar/Orpesa  40.09225   0.133988    28.014260            oropesadelmar             orpesa
# 7789             Valencia  Castellón                                   Palanques  40.71812  -0.180570   670.436800                palanques               None
# 7790             Valencia  Castellón                                      Pavías  39.97375  -0.482402   743.471600                   pavias               None
# 7791             Valencia  Castellón                         Peníscola/Peñíscola  40.36029   0.402851     6.325546                peniscola          peniscola
# 7792             Valencia  Castellón                          Pina de Montalgrao  40.02067  -0.654830  1035.532000         pinademontalgrao               None
# 7793             Valencia  Castellón                     Pobla de Benifassà (la)  40.35000   0.400000     0.000000       pobladebenifassala               None
# 7794             Valencia  Castellón                          Pobla Tornesa (la)  40.10108  -0.000988   302.006100           poblatornesala               None
# 7795             Valencia  Castellón                          Portell de Morella  40.53268  -0.262055  1073.041000         portelldemorella               None
# 7796             Valencia  Castellón                           Puebla de Arenoso  40.10384  -0.592726   631.926000          puebladearenoso               None
# 7797             Valencia  Castellón                                  Ribesalbes  40.02246  -0.274931   190.101900               ribesalbes               None
# 7798             Valencia  Castellón                                     Rossell  40.61636   0.220546   462.529800                  rossell               None
# 7799             Valencia  Castellón                                     Sacañet  39.85283  -0.714478  1010.367000                  sacanet               None
# 7800             Valencia  Castellón                             Salzadella (la)  40.41933   0.175213   338.238100             salzadellala               None
# 7801             Valencia  Castellón                          San Rafael del Río  40.60630   0.349894   249.519800          sanrafaeldelrio               None
# 7802             Valencia  Castellón                           Sant Joan de Moró  40.06081  -0.137161   189.678300           santjoandemoro               None
# 7803             Valencia  Castellón                        Sant Jordi/San Jorge  40.46417   0.354712   102.603200                santjordi           sanjorge
# 7804             Valencia  Castellón                                  Sant Mateu  40.46391   0.178263   331.450800                santmateu               None
# 7805             Valencia  Castellón                   Santa Magdalena de Pulpis  40.35590   0.302428   123.850200   santamagdalenadepulpis               None
# 7806             Valencia  Castellón                                  Sarratella  40.31277   0.030029   784.202700               sarratella               None
# 7807             Valencia  Castellón                                     Segorbe  39.85328  -0.484994   375.604900                  segorbe               None
# 7808             Valencia  Castellón                           Sierra Engarcerán  40.26946  -0.019144   750.290200         sierraengarceran               None
# 7809             Valencia  Castellón                                      Soneja  39.81681  -0.428956   267.858900                   soneja               None
# 7810             Valencia  Castellón                               Sot de Ferrer  39.80494  -0.410224   235.519100              sotdeferrer               None
# 7811             Valencia  Castellón                                Sueras/Suera  39.95241  -0.329884   298.399200                   sueras              suera
# 7812             Valencia  Castellón                                       Tales  39.94829  -0.307358   247.661500                    tales               None
# 7813             Valencia  Castellón                                      Teresa  39.90000  -0.659247   626.568900                   teresa               None
# 7814             Valencia  Castellón                                       Tírig  40.42364   0.077462   468.782700                    tirig               None
# 7815             Valencia  Castellón                                   Todolella  40.64658  -0.247922   783.975600                todolella               None
# 7816             Valencia  Castellón                                        Toga  40.04161  -0.367715   296.150500                     toga               None
# 7817             Valencia  Castellón                                       Torás  39.91962  -0.686733   774.251700                    toras               None
# 7818             Valencia  Castellón                                   Toro (El)  39.96720  -0.053783    32.423480                   toroel               None
# 7819             Valencia  Castellón                          Torralba del Pinar  39.98846  -0.438430   731.164800         torralbadelpinar               None
# 7820             Valencia  Castellón                      Torre d'En Besora (la)  39.98182  -0.072121    57.745680        torred'enbesorala               None
# 7821             Valencia  Castellón                     Torre d'en Doménec (la)  40.26389   0.069759   309.272300       torred'endomenecla               None
# 7822             Valencia  Castellón                                 Torreblanca  40.22024   0.195593    34.196300              torreblanca               None
# 7823             Valencia  Castellón                                  Torrechiva  40.04980  -0.397193   349.240500               torrechiva               None
# 7824             Valencia  Castellón                                   Traiguera  40.52502   0.293772   253.979800                traiguera               None
# 7825             Valencia  Castellón                         Useras/Useres (les)  40.22735  -0.080291   312.852600                   useras          useresles
# 7826             Valencia  Castellón                                 Vall d'Alba  40.17512  -0.034612   299.738800               valld'alba               None
# 7827             Valencia  Castellón                            Vall d'Uixó (la)  39.82333  -0.232562   120.375900             valld'uixola               None
# 7828             Valencia  Castellón                           Vall de Almonacid  39.90323  -0.456265   436.314500          valldealmonacid               None
# 7829             Valencia  Castellón                                      Vallat  40.02964  -0.336432   263.303300                   vallat               None
# 7830             Valencia  Castellón                                   Vallibona  40.60295   0.046235   661.419400                vallibona               None
# 7831             Valencia  Castellón                                   Vila-real  39.93835  -0.101829    46.860890                 vilareal               None
# 7832             Valencia  Castellón                                   Vilafamés  40.11403  -0.052981   318.605500                vilafames               None
# 7833             Valencia  Castellón                          Vilanova d'Alcolea  40.23169   0.073621   349.054000        vilanovad'alcolea               None
# 7834             Valencia  Castellón                              Vilar de Canes  40.35885  -0.065210   663.040800             vilardecanes               None
# 7835             Valencia  Castellón                              Vilavella (la)  39.85938  -0.183521    37.974320              vilavellala               None
# 7836             Valencia  Castellón              Villafranca del Cid/Vilafranca  40.42710  -0.257748  1129.053000        villafrancadelcid         vilafranca
# 7837             Valencia  Castellón                        Villahermosa del Río  40.20107  -0.418598   739.184100       villahermosadelrio               None
# 7838             Valencia  Castellón                                  Villamalur  39.96404  -0.394593   638.889000               villamalur               None
# 7839             Valencia  Castellón                         Villanueva de Viver  40.05904  -0.646767   895.273600        villanuevadeviver               None
# 7840             Valencia  Castellón                                    Villores  40.67530  -0.200124   732.960400                 villores               None
# 7841             Valencia  Castellón                                     Vinaròs  40.47100   0.474743    12.065500                  vinaros               None
# 7842             Valencia  Castellón                   Vistabella del Maestrazgo  40.29388  -0.294031  1249.736000  vistabelladelmaestrazgo               None
# 7843             Valencia  Castellón                                       Viver  39.92135  -0.594422   552.364400                    viver               None
# 7844             Valencia  Castellón                       Zorita del Maestrazgo  40.72866  -0.164694   652.530200      zoritadelmaestrazgo               None
# 7845             Valencia  Castellón                                     Zucaina  40.13165  -0.420668   813.702400                  zucaina               None

# %%
municipalities_to_change = [
    
    # Álava
        "Iruña Oka", "Erriberagoitia", 
    # Gipuzkoa
        "Arrasate", "Soraluze", 
    # Bizkaia
        "Karrantza Harana", "Urduña"
    # Alicante
        "Fondó de les Neus (el)", "Pinós (el)", 
    #
        "Montitxelvo", "Peníscola", "Borriana", "Sant Jordi","Harana", 
     # Navarra
        'Abaurregaina', 'Abaurrepea', 'Altsasu', 
       'Auritz', 'Bera', 
       'Doneztebe', 'Hiriberri',
       'Luzaide', 'Olazti',
        'Orreaga' ]

# %%
# df_municipalities_coordinates.loc[(df_municipalities_coordinates["language"]) & (df_municipalities_coordinates["province"] == "Valencia")]

# %%
municipalities_to_change = ["Iruña Oka", "Harana", "Erriberagoitia", "Fondó de les Neus (el)", "Pinós (el)", "Montitxelvo", "Peníscola", "Borriana", "Sant Jordi", "Arrasate", "Soraluze", "Karrantza Harana", "Urduña"
                            'Abaurregaina', 'Abaurrepea', 'Aibar', 'Altsasu', 'Aoiz', 'Arce',
       'Auritz', 'Bera', 'Burgui',
       'Doneztebe', 'Esparza de Salazar', 'Hiriberri',
       'Luzaide', 'Olazti',
        'Orreaga' ]

# Assign "change" to the new column where language=True and municipality_1 is in the list
df_municipalities_coordinates.loc[
    (df_municipalities_coordinates["language"]) & 
    (df_municipalities_coordinates["municipality_spa"].isin(municipalities_to_change)), 
    "change"
] = "change"

# %%
df_municipalities_coordinates.loc[df_municipalities_coordinates["change"] == "change", ["municipality_spa", "municipality_2"]] = df_municipalities_coordinates.loc[df_municipalities_coordinates["change"] == "change", ["municipality_2", "municipality_spa"]].values

# %% [markdown]
# After all of this changes --> municipality_1 is in spanish / municipality_2 is in the province language

# %% [markdown]
# ___

# %% [markdown]
# Let's do the same with the towns db

# %%
df_municipalities.head()
# Out:
#    CPRO province  CMUN      municipality
# 0     1    Álava     1  Alegría-Dulantzi
# 1     1    Álava     2           Amurrio
# 2     1    Álava     3           Aramaio
# 3     1    Álava     4        Artziniega
# 4     1    Álava     6           Armiñón

# %%
df_municipalities[['municipality_spa', 'municipality_2']] = df_municipalities['municipality'].str.split('/', n=1, expand=True)
df_municipalities.head()
# Out:
#    CPRO province  CMUN      municipality  municipality_spa municipality_2
# 0     1    Álava     1  Alegría-Dulantzi  Alegría-Dulantzi           None
# 1     1    Álava     2           Amurrio           Amurrio           None
# 2     1    Álava     3           Aramaio           Aramaio           None
# 3     1    Álava     4        Artziniega        Artziniega           None
# 4     1    Álava     6           Armiñón           Armiñón           None

# %%
df_municipalities["language"] = df_municipalities["municipality_2"].notna()
df_municipalities.head()
# Out:
#    CPRO province  CMUN      municipality  municipality_spa municipality_2  \
# 0     1    Álava     1  Alegría-Dulantzi  Alegría-Dulantzi           None
# 1     1    Álava     2           Amurrio           Amurrio           None
# 2     1    Álava     3           Aramaio           Aramaio           None
# 3     1    Álava     4        Artziniega        Artziniega           None
# 4     1    Álava     6           Armiñón           Armiñón           None
#
#    language
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False

# %%
df_municipalities[df_municipalities["municipality_2"].notna()]["province"].unique()
# Out:
# array(['Álava', 'Alicante', 'Castellón', 'Gipuzkoa', 'Navarra',
#        'Valencia', 'Bizkaia'], dtype=object)

# %%
municipalities_to_change = [
    
#álava
"Iruña Oka", "Harana",
     
#alicante
'Alcoi', 'Alacant', 'Poble Nou de Benitatxell, el',
       'Camp de Mirra, el', 'Elx', 'Fondó de les Neus, el', 'Xàbia',
       'Xixona', "Orxa, l'", 'Monòver', 'Pinós, el',
       'Sant Vicent del Raspeig', 'Torre de les Maçanes, la',
       'Vila Joiosa, la', 
#castellón
       'Benicàssim', 'Borriana',  'Xodos', 'Llucena', 'Orpesa',
       'Peníscola', 'Sant Jordi', 'Suera', 'Useres, les', 'Vilafranca',
       'Alqueries, les',
#gipuzkoa
       "Arrasate", "Donostia"

#navarra
       'Abaurregaina', 'Abaurrepea', 'Altsasu', 'Auritz', 'Olazti', 'Orreaga',  'Sangüesa', 'Doneztebe',

#valencia
'Alboraia', 'Moixent', 'Montitxelvo', 'Montroi', 'Nàquera',
       'Sagunt', 'Vilallonga'

#Bizkaia
"Karrantza Harana", "Urduña"]

# %%
# Assign "change" to the new column where language=True and municipality_1 is in the list
df_municipalities.loc[
    (df_municipalities["language"]) & 
    (df_municipalities["municipality_spa"].isin(municipalities_to_change)), 
    "change"
] = "change"

# %%
df_municipalities.loc[df_municipalities["change"] == "change", ["municipality_spa", "municipality_2"]] = df_municipalities.loc[df_municipalities["change"] == "change", ["municipality_2", "municipality_spa"]].values

# %% [markdown]
# ---

# %% [markdown]
# ## Now clean and match on municipalities SPA

# %%
cleaner = AccentCleaner([df_municipalities, df_municipalities_coordinates], ['municipality_spa'])
cleaner.cleanAccents()

# %%
# aligner = ColumnAligner(df_municipalities, df_municipalities_coordinates, 'municipality_clean', re.compile(r"\*,\s"))
# aligner.alignColumns()

# %%
df_municipalities['municipality_spa_clean'] = df_municipalities['municipality_spa_clean'].str.replace(" ","")
df_municipalities['municipality_spa_clean'] = df_municipalities['municipality_spa_clean'].str.replace(",","")
df_municipalities['municipality_spa_clean'] = df_municipalities['municipality_spa_clean'].str.replace("(","")
df_municipalities['municipality_spa_clean'] = df_municipalities['municipality_spa_clean'].str.replace(")","")
df_municipalities['municipality_spa_clean'] = df_municipalities['municipality_spa_clean'].str.replace("-","")
df_municipalities['municipality_spa_clean'] = df_municipalities['municipality_spa_clean'].str.replace("ñ","n")

# %%
df_municipalities_coordinates['municipality_spa_clean'] = df_municipalities_coordinates['municipality_spa_clean'].str.replace(" ","")
df_municipalities_coordinates['municipality_spa_clean'] = df_municipalities_coordinates['municipality_spa_clean'].str.replace(",","")
df_municipalities_coordinates['municipality_spa_clean'] = df_municipalities_coordinates['municipality_spa_clean'].str.replace("(","")
df_municipalities_coordinates['municipality_spa_clean'] = df_municipalities_coordinates['municipality_spa_clean'].str.replace(")","")
df_municipalities_coordinates['municipality_spa_clean'] = df_municipalities_coordinates['municipality_spa_clean'].str.replace("-","")
df_municipalities_coordinates['municipality_spa_clean'] = df_municipalities_coordinates['municipality_spa_clean'].str.replace("ñ","n")

# %%
df_municipalities.head()
# Out:
#    CPRO province  CMUN      municipality  municipality_spa municipality_2  \
# 0     1    Álava     1  Alegría-Dulantzi  Alegría-Dulantzi           None
# 1     1    Álava     2           Amurrio           Amurrio           None
# 2     1    Álava     3           Aramaio           Aramaio           None
# 3     1    Álava     4        Artziniega        Artziniega           None
# 4     1    Álava     6           Armiñón           Armiñón           None
#
#    language change municipality_spa_clean
# 0     False    NaN        alegriadulantzi
# 1     False    NaN                amurrio
# 2     False    NaN                aramaio
# 3     False    NaN             artziniega
# 4     False    NaN                arminon

# %%
df_municipalities_coordinates.head()
# Out:
#   autonomous_community province municipality  latitude  longitude   altitude  \
# 0            Andalucía  Almería         Abla  37.14114  -2.780104  871.16840
# 1            Andalucía  Almería     Abrucena  37.13305  -2.797098  976.93870
# 2            Andalucía  Almería         Adra  36.74807  -3.022522   10.97898
# 3            Andalucía  Almería    Albánchez  37.28710  -2.181163  481.31230
# 4            Andalucía  Almería    Alboloduy  37.03319  -2.621750  388.43460
#
#   municipality_spa municipality_2  language change municipality_spa_clean
# 0             Abla           None     False    NaN                   abla
# 1         Abrucena           None     False    NaN               abrucena
# 2             Adra           None     False    NaN                   adra
# 3        Albánchez           None     False    NaN              albanchez
# 4        Alboloduy           None     False    NaN              alboloduy

# %%
df_municipalities_coordinates['municipality_spa_clean'] = df_municipalities_coordinates['municipality_spa_clean'].str.replace(r"[\u200b\u2060]", "", regex=True)  # Remove zero-width spaces
df_municipalities['municipality_spa_clean'] = df_municipalities['municipality_spa_clean'].str.replace(r"[\u200b\u2060]", "", regex=True)  # Remove zero-width spaces

# %%
df = df_municipalities.merge(df_municipalities_coordinates, on = "municipality_spa_clean", how='left')

# %%
df.isna().sum()
# Out:
# CPRO                         0
# province_x                   0
# CMUN                         0
# municipality_x               0
# municipality_spa_x           0
# municipality_2_x          8040
# language_x                   0
# change_x                  8124
# municipality_spa_clean       0
# autonomous_community       117
# province_y                 117
# municipality_y             117
# latitude                   117
# longitude                  117
# altitude                   117
# municipality_spa_y         117
# municipality_2_y          8093
# language_y                 117
# change_y                  8151
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (8166, 19)

# %%
df.columns
# Out:
# Index(['CPRO', 'province_x', 'CMUN', 'municipality_x', 'municipality_spa_x',
#        'municipality_2_x', 'language_x', 'change_x', 'municipality_spa_clean',
#        'autonomous_community', 'province_y', 'municipality_y', 'latitude',
#        'longitude', 'altitude', 'municipality_spa_y', 'municipality_2_y',
#        'language_y', 'change_y'],
#       dtype='object')

# %%
df = df[['CPRO', 'province_x', 'CMUN', 'municipality_x', 'municipality_spa_x',
       'autonomous_community',   'latitude',
       'longitude', 'altitude']]

# %%
df.rename(columns={      "province_x": "province",
                          "municipality_x": "municipality", 
                          'municipality_spa_x': "municipality_spa"}, inplace=True)

# %%
df.columns
# Out:
# Index(['CPRO', 'province', 'CMUN', 'municipality', 'municipality_spa',
#        'autonomous_community', 'latitude', 'longitude', 'altitude'],
#       dtype='object')

# %%
df.shape
# Out:
# (8166, 9)

# %%
def get_zeros(stringlength, fill_length):
    if stringlength < fill_length:
        return '0'* (fill_length - stringlength)
    return None


df["CPRO"] = df["CPRO"].astype(str)
df["CMUN"] = df["CMUN"].astype(str)

df["CPRO"] = df["CPRO"].apply(lambda x: '0' + x if len(x) < 2 else x )
df["CMUN"] = df["CMUN"].apply(lambda x: get_zeros(len(x), 3) + x if len(x) < 3 else x)

df['cmun'] = df["CPRO"] + df["CMUN"]
df.cmun = df.cmun.astype("int32")

# %%
df
# Out:
#      CPRO  province CMUN           municipality       municipality_spa  \
# 0      01     Álava  001       Alegría-Dulantzi       Alegría-Dulantzi
# 1      01     Álava  002                Amurrio                Amurrio
# 2      01     Álava  003                Aramaio                Aramaio
# 3      01     Álava  004             Artziniega             Artziniega
# 4      01     Álava  006                Armiñón                Armiñón
# ...   ...       ...  ...                    ...                    ...
# 8161   50  Zaragoza  901                   Biel                   Biel
# 8162   50  Zaragoza  902               Marracos               Marracos
# 8163   50  Zaragoza  903  Villamayor de Gállego  Villamayor de Gállego
# 8164   51     Ceuta  001                  Ceuta                  Ceuta
# 8165   52   Melilla  001                Melilla                Melilla
#
#      autonomous_community  latitude  longitude   altitude   cmun
# 0              País Vasco  42.84149  -2.513507  561.68570   1001
# 1              País Vasco  43.05265  -3.001022  219.69100   1002
# 2              País Vasco  43.05400  -2.566000  381.87970   1003
# 3              País Vasco  43.12220  -3.128209  196.98080   1004
# 4              País Vasco  42.72305  -2.872574  463.58150   1006
# ...                   ...       ...        ...        ...    ...
# 8161               Aragón  42.38749  -0.936588  754.24450  50901
# 8162               Aragón  42.09059  -0.776047  404.73610  50902
# 8163               Aragón  41.68518  -0.773315  231.12340  50903
# 8164      Ceuta y Melilla  35.88829  -5.316195   13.47725  51001
# 8165      Ceuta y Melilla  35.29234  -2.938794   10.33370  52001
#
# [8166 rows x 10 columns]

# %%
df.columns
# Out:
# Index(['CPRO', 'province', 'CMUN', 'municipality', 'municipality_spa',
#        'autonomous_community', 'latitude', 'longitude', 'altitude', 'cmun'],
#       dtype='object')

# %%
df = df[['cmun', 'municipality_spa', 'province',  
       'autonomous_community', 'latitude', 'longitude', 'altitude', 'municipality']]

# %%
df.isna().sum()
# Out:
# cmun                      0
# municipality_spa          0
# province                  0
# autonomous_community    117
# latitude                117
# longitude               117
# altitude                117
# municipality              0
# dtype: int64

# %%
df[df["latitude"].isna()]["province"].unique()
# Out:
# array(['Álava', 'Alicante', 'Almería', 'Ávila', 'Badajoz',
#        'Illes Balears', 'Barcelona', 'Burgos', 'Cáceres', 'Cádiz',
#        'Castellón', 'Córdoba', 'A Coruña', 'Cuenca', 'Girona', 'Granada',
#        'Gipuzkoa', 'Huelva', 'Huesca', 'León', 'La Rioja', 'Madrid',
#        'Málaga', 'Navarra', 'Pontevedra', 'Santa Cruz de Tenerife',
#        'Segovia', 'Sevilla', 'Tarragona', 'Toledo', 'Valencia', 'Bizkaia',
#        'Zamora', 'Zaragoza'], dtype=object)

# %%
df = df.drop(df[df["latitude"].isna() & df["province"].isin([
    'Almería', 'Ávila', 'Badajoz', 'Illes Balears', 'Barcelona', 'Burgos',
    'Cáceres', 'Cádiz', 'Córdoba', 'A Coruña', 'Cuenca', 'Girona', 'Granada',
    'Huelva', 'Huesca', 'León', 'La Rioja', 'Madrid', 'Málaga', 'Pontevedra',
    'Santa Cruz de Tenerife', 'Segovia', 'Sevilla', 'Tarragona', 'Toledo',
    'Zamora', 'Zaragoza'
])].index)

# %%
df.isna().sum()
# Out:
# cmun                     0
# municipality_spa         0
# province                 0
# autonomous_community    63
# latitude                63
# longitude               63
# altitude                63
# municipality             0
# dtype: int64

# %%
df.dropna(subset=["latitude"], inplace=True)

# %%
df[df["municipality"] == "Donostia"]
# Out:
# Empty DataFrame
# Columns: [cmun, municipality_spa, province, autonomous_community, latitude, longitude, altitude, municipality]
# Index: []

# %%
df.to_csv("../data/processed/filtered_municipalities.csv", index=False)
